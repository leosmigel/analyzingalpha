# %% [markdown]
# ## FTX.US API in Python Tutorial

# %% [markdown]
# ### Get Required Imports

# %%
import datetime
import requests
import pandas as pd
from client import FtxClient 
from local_settings import ftxus as settings

# %% [markdown]
# ### Using the FTX Market API

# %% [markdown]
# Using the Markets API is easy. The Markets API allows us to get all of the market data. We'll be greeted with the following information when we make a request.

# %% [markdown]
# | Field                 | Type    | Value    | Description                                                                                                               |
# | --------------------- | ------- | -------- | ------------------------------------------------------------------------------------------------------------------------- |
# | name                  | string  | BTC-0628 | e.g. "BTC/USD" for spot, "BTC-PERP" for futures                                                                           |
# | baseCurrency          | string  | BTC      | spot markets only                                                                                                         |
# | quoteCurrency         | string  | USD      | spot markets only                                                                                                         |
# | quoteVolume24h        | number  | 28914.76 |                                                                                                                           |
# | change1h              | number  | 0.012    | change in the past hour                                                                                                   |
# | change24h             | number  | 0.0299   | change in the past 24 hours                                                                                               |
# | changeBod             | number  | 0.0156   | change since start of day (00:00 UTC)                                                                                     |
# | highLeverageFeeExempt | boolean | false    |                                                                                                                           |
# | minProvideSize        | number  | 0.001    | Minimum maker order size (if >10 orders per hour fall below this size)                                                    |
# | type                  | string  | future   | "future" or "spot"                                                                                                        |
# | underlying            | string  | BTC      | future markets only                                                                                                       |
# | enabled               | boolean | true     |                                                                                                                           |
# | ask                   | number  | 3949.25  | best ask                                                                                                                  |
# | bid                   | number  | 3949.00  | best bid                                                                                                                  |
# | last                  | number  | 3949.00  | last traded price                                                                                                         |
# | postOnly              | boolean | false    | if the market is in post-only mode (all orders get modified to be post-only, in addition to other settings they may have) |
# | price                 | number  | 10579.52 | current price                                                                                                             |
# | priceIncrement        | number  | 0.25     |                                                                                                                           |
# | sizeIncrement         | number  | 0.0001   |                                                                                                                           |
# | restricted            | boolean | false    | if the market has nonstandard restrictions on which jurisdictions can trade it                                            |
# | volumeUsd24h          | number  | 28914.76 | USD volume in past 24 hours                                                                                               |

# %% [markdown]
# ### Get All Market Data

# %% [markdown]
# Let's start by getting all available markets. We need to use the requests library to request the appropriate API endpoint.

# %%
# GET /markets
api_url = 'https://ftx.us/api'
api = '/markets'
url = api_url+api
url
# Out:
# 'https://ftx.us/api/markets'

# %% [markdown]
# Now we'll use requests to get the market response data.

# %%
markets = requests.get(url).json()
data = markets['result']
data
# Out:
# [{'name': 'AAVE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 124.14,
#   'bid': 124.2,
#   'ask': 124.69,
#   'price': 124.2,
#   'type': 'spot',
#   'baseCurrency': 'AAVE',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.03431045969353764,
#   'change24h': -0.09777713206450675,
#   'changeBod': -0.047619047619047616,
#   'quoteVolume24h': 165801.9836,
#   'volumeUsd24h': 165801.9836},
#  {'name': 'AAVE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 124.58,
#   'bid': 124.16,
#   'ask': 124.55,
#   'price': 124.55,
#   'type': 'spot',
#   'baseCurrency': 'AAVE',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.037484381507705125,
#   'change24h': -0.09484011627906977,
#   'changeBod': -0.04603247549019608,
#   'quoteVolume24h': 30021.5859,
#   'volumeUsd24h': 30039.55141743428},
#  {'name': 'AUD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.7168,
#   'bid': 0.7149,
#   'ask': 0.7152,
#   'price': 0.7152,
#   'type': 'spot',
#   'baseCurrency': 'AUD',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.0014001680201624195,
#   'change24h': -0.011745198286582837,
#   'changeBod': -0.009829710646545756,
#   'quoteVolume24h': 1733.2224,
#   'volumeUsd24h': 1733.2224},
#  {'name': 'AVAX/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-07,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.0019803,
#   'bid': 0.0019822,
#   'ask': 0.0019881,
#   'price': 0.0019822,
#   'type': 'spot',
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.016617088932198175,
#   'change24h': -0.0344390861707828,
#   'changeBod': -0.0022650626667337797,
#   'quoteVolume24h': 5.0054736,
#   'volumeUsd24h': 183306.321630163},
#  {'name': 'AVAX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 72.121,
#   'bid': 72.656,
#   'ask': 72.8565,
#   'price': 72.656,
#   'type': 'spot',
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.03606314258416872,
#   'change24h': -0.06449494624348162,
#   'changeBod': -0.016647267411958964,
#   'quoteVolume24h': 8024211.1774,
#   'volumeUsd24h': 8024211.1774},
#  {'name': 'AVAX/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 72.1625,
#   'bid': 72.59,
#   'ask': 72.7855,
#   'price': 72.59,
#   'type': 'spot',
#   'baseCurrency': 'AVAX',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.03588272648785952,
#   'change24h': -0.06444129398118315,
#   'changeBod': -0.01967669183086418,
#   'quoteVolume24h': 457673.06075,
#   'volumeUsd24h': 457946.941463014},
#  {'name': 'BAT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.627925,
#   'bid': 0.6289,
#   'ask': 0.630275,
#   'price': 0.6289,
#   'type': 'spot',
#   'baseCurrency': 'BAT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.02614725678156231,
#   'change24h': -0.0830022235993147,
#   'changeBod': -0.040140415140415144,
#   'quoteVolume24h': 67567.058925,
#   'volumeUsd24h': 67567.058925},
#  {'name': 'BCH/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.007854,
#   'bid': 0.007852,
#   'ask': 0.00786,
#   'price': 0.007854,
#   'type': 'spot',
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1500.0,
#   'change1h': 0.023856081345326553,
#   'change24h': 0.003834355828220859,
#   'changeBod': 0.015647226173541962,
#   'quoteVolume24h': 9.26111131,
#   'volumeUsd24h': 339152.7723657558},
#  {'name': 'BCH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 286.5,
#   'bid': 287.25,
#   'ask': 287.825,
#   'price': 287.25,
#   'type': 'spot',
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1500.0,
#   'change1h': 0.03934871099050204,
#   'change24h': -0.029806636831883813,
#   'changeBod': -0.0039875173370319,
#   'quoteVolume24h': 3470318.1057,
#   'volumeUsd24h': 3470318.1057},
#  {'name': 'BCH/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 287.025,
#   'bid': 287.075,
#   'ask': 287.925,
#   'price': 287.075,
#   'type': 'spot',
#   'baseCurrency': 'BCH',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1500.0,
#   'change1h': 0.03843371314885151,
#   'change24h': -0.029906226239756695,
#   'changeBod': -0.004680592875097513,
#   'quoteVolume24h': 3879183.1019,
#   'volumeUsd24h': 3881504.482651839},
#  {'name': 'BRZ/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.19574,
#   'bid': 0.19323,
#   'ask': 0.19471,
#   'price': 0.19471,
#   'type': 'spot',
#   'baseCurrency': 'BRZ',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.005889342356770161,
#   'change24h': -0.020327044025157233,
#   'changeBod': -0.02003120438874629,
#   'quoteVolume24h': 716.39233,
#   'volumeUsd24h': 716.39233},
#  {'name': 'BRZ/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.19327,
#   'bid': 0.19298,
#   'ask': 0.19472,
#   'price': 0.19327,
#   'type': 'spot',
#   'baseCurrency': 'BRZ',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.0,
#   'change24h': -0.02369165487977369,
#   'changeBod': -0.022061427920862218,
#   'quoteVolume24h': 27.27734,
#   'volumeUsd24h': 27.2936633058028},
#  {'name': 'BTC/AUD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 48320.0,
#   'bid': 51156.0,
#   'ask': 51288.0,
#   'price': 51156.0,
#   'type': 'spot',
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'AUD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.01869884700400263,
#   'change24h': -0.0225652979727535,
#   'changeBod': -0.012108220844678755,
#   'quoteVolume24h': 9.664,
#   'volumeUsd24h': 6.900096},
#  {'name': 'BTC/BRZ',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 195245.0,
#   'bid': 188240.0,
#   'ask': 189790.0,
#   'price': 189790.0,
#   'type': 'spot',
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'BRZ',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.01600642398286938,
#   'change24h': -0.005736438169578542,
#   'changeBod': 0.007886142162980272,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0},
#  {'name': 'BTC/EUR',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 32677.0,
#   'bid': 32642.0,
#   'ask': 32744.0,
#   'price': 32677.0,
#   'type': 'spot',
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'EUR',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.011546557701832591,
#   'change24h': -0.021705287108556372,
#   'changeBod': -0.007260906550006076,
#   'quoteVolume24h': 2754.6029,
#   'volumeUsd24h': 3085.155248},
#  {'name': 'BTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 36667.0,
#   'bid': 36640.0,
#   'ask': 36663.0,
#   'price': 36663.0,
#   'type': 'spot',
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.018812871672317013,
#   'change24h': -0.03059227921734532,
#   'changeBod': -0.016893250744107472,
#   'quoteVolume24h': 113807881.0619,
#   'volumeUsd24h': 113807881.0619},
#  {'name': 'BTC/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 36575.0,
#   'bid': 36608.0,
#   'ask': 36653.0,
#   'price': 36608.0,
#   'type': 'spot',
#   'baseCurrency': 'BTC',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.017623839439595262,
#   'change24h': -0.03220007402315867,
#   'changeBod': -0.018183768706753204,
#   'quoteVolume24h': 7958257.7072,
#   'volumeUsd24h': 7963020.087777142},
#  {'name': 'CAD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.7814,
#   'bid': 0.7806,
#   'ask': 0.7807,
#   'price': 0.7807,
#   'type': 'spot',
#   'baseCurrency': 'CAD',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.001796484024124214,
#   'change24h': -0.006616617890316834,
#   'changeBod': -0.00611075747931254,
#   'quoteVolume24h': 268.6226,
#   'volumeUsd24h': 268.6226},
#  {'name': 'CUSDT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.021565,
#   'bid': 0.02158,
#   'ask': 0.021665,
#   'price': 0.02158,
#   'type': 'spot',
#   'baseCurrency': 'CUSDT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.0004636068613815484,
#   'change24h': -0.002542177027963947,
#   'changeBod': -0.002542177027963947,
#   'quoteVolume24h': 2.47979,
#   'volumeUsd24h': 2.47979},
#  {'name': 'CUSDT/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.02165,
#   'bid': 0.02165,
#   'ask': 0.02174,
#   'price': 0.02165,
#   'type': 'spot',
#   'baseCurrency': 'CUSDT',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0},
#  {'name': 'DAI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.0001,
#   'bid': 1.0,
#   'ask': 1.0001,
#   'price': 1.0001,
#   'type': 'spot',
#   'baseCurrency': 'DAI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.0,
#   'change24h': 0.0001,
#   'changeBod': 0.0001,
#   'quoteVolume24h': 3090.11038,
#   'volumeUsd24h': 3090.11038},
#  {'name': 'DAI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.9991,
#   'bid': 0.9988,
#   'ask': 1.0001,
#   'price': 0.9991,
#   'type': 'spot',
#   'baseCurrency': 'DAI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.0,
#   'change24h': 0.00020022024226649314,
#   'changeBod': 0.00020022024226649314,
#   'quoteVolume24h': 499.55,
#   'volumeUsd24h': 499.848940711},
#  {'name': 'DOGE/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 3.32e-06,
#   'bid': 3.27e-06,
#   'ask': 3.29e-06,
#   'price': 3.29e-06,
#   'type': 'spot',
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.0,
#   'change24h': -0.05187319884726225,
#   'changeBod': -0.03519061583577713,
#   'quoteVolume24h': 23.0740137,
#   'volumeUsd24h': 844997.4796772453},
#  {'name': 'DOGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.119765,
#   'bid': 0.120229,
#   'ask': 0.120327,
#   'price': 0.120229,
#   'type': 'spot',
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.016980836819021922,
#   'change24h': -0.08379849952943597,
#   'changeBod': -0.053393223394916166,
#   'quoteVolume24h': 1514095.1803775,
#   'volumeUsd24h': 1514095.1803775},
#  {'name': 'DOGE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1197745,
#   'bid': 0.1201115,
#   'ask': 0.120328,
#   'price': 0.1201115,
#   'type': 'spot',
#   'baseCurrency': 'DOGE',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.017402610603352617,
#   'change24h': -0.08350310938155736,
#   'changeBod': -0.05476115526874951,
#   'quoteVolume24h': 119595.3930825,
#   'volumeUsd24h': 119666.96135762843},
#  {'name': 'ETH/AUD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 3918.3,
#   'bid': 3546.9,
#   'ask': 3577.8,
#   'price': 3577.8,
#   'type': 'spot',
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'AUD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.039061365550489356,
#   'change24h': -0.025202299539547175,
#   'changeBod': -0.00016767270288397049,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0},
#  {'name': 'ETH/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.06939,
#   'bid': 0.0693375,
#   'ask': 0.0694125,
#   'price': 0.06939,
#   'type': 'spot',
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.01894273127753304,
#   'change24h': -0.011327206668091472,
#   'changeBod': 0.004087834171399631,
#   'quoteVolume24h': 34.341667115,
#   'volumeUsd24h': 1257632.1803991098},
#  {'name': 'ETH/EUR',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 2493.7,
#   'bid': 2263.1,
#   'ask': 2276.1,
#   'price': 2276.1,
#   'type': 'spot',
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'EUR',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.038177339901477834,
#   'change24h': -0.03099323087402614,
#   'changeBod': -0.0026728595215143283,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0},
#  {'name': 'ETH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 2543.9,
#   'bid': 2542.3,
#   'ask': 2543.8,
#   'price': 2543.8,
#   'type': 'spot',
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.03870967741935484,
#   'change24h': -0.04220791445461049,
#   'changeBod': -0.013036393264530146,
#   'quoteVolume24h': 65957059.6477,
#   'volumeUsd24h': 65957059.6477},
#  {'name': 'ETH/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 2526.3,
#   'bid': 2540.0,
#   'ask': 2542.5,
#   'price': 2540.0,
#   'type': 'spot',
#   'baseCurrency': 'ETH',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.0380057212913772,
#   'change24h': -0.04309825195901145,
#   'changeBod': -0.013783731314307901,
#   'quoteVolume24h': 15581456.9873,
#   'volumeUsd24h': 15590781.24279034},
#  {'name': 'EUR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.1118,
#   'bid': 1.1183,
#   'ask': 1.1224,
#   'price': 1.1183,
#   'type': 'spot',
#   'baseCurrency': 'EUR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.0022405449005198064,
#   'change24h': -0.012538631346578366,
#   'changeBod': -0.01061665044678404,
#   'quoteVolume24h': 2277.0598,
#   'volumeUsd24h': 2277.0598},
#  {'name': 'GBP/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.3342,
#   'bid': 1.3375,
#   'ask': 1.3376,
#   'price': 1.3375,
#   'type': 'spot',
#   'baseCurrency': 'GBP',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.001122754491017964,
#   'change24h': -0.012404932437421546,
#   'changeBod': -0.012186115214180207,
#   'quoteVolume24h': 1102.2964,
#   'volumeUsd24h': 1102.2964},
#  {'name': 'GRT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3424,
#   'bid': 0.34225,
#   'ask': 0.3427,
#   'price': 0.3424,
#   'type': 'spot',
#   'baseCurrency': 'GRT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.0331925165962583,
#   'change24h': -0.0729660213889265,
#   'changeBod': -0.033996332345887996,
#   'quoteVolume24h': 1121174.076,
#   'volumeUsd24h': 1121174.076},
#  {'name': 'KSHIB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.023291,
#   'bid': 0.023395,
#   'ask': 0.023454,
#   'price': 0.023395,
#   'type': 'spot',
#   'baseCurrency': 'KSHIB',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.03302865721729147,
#   'change24h': -0.10828632413477664,
#   'changeBod': -0.058134385442248075,
#   'quoteVolume24h': 156493.50157,
#   'volumeUsd24h': 156493.50157},
#  {'name': 'LINK/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.00034885,
#   'bid': 0.00034805,
#   'ask': 0.00034895,
#   'price': 0.00034885,
#   'type': 'spot',
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.01616661811826391,
#   'change24h': -0.05575856002165381,
#   'changeBod': -0.025694735372154727,
#   'quoteVolume24h': 1.38736692,
#   'volumeUsd24h': 50807.005925786645},
#  {'name': 'LINK/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 12.773,
#   'bid': 12.765,
#   'ask': 12.7725,
#   'price': 12.7725,
#   'type': 'spot',
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.03521640460366348,
#   'change24h': -0.08535930394930001,
#   'changeBod': -0.044403710908274725,
#   'quoteVolume24h': 4349687.16775,
#   'volumeUsd24h': 4349687.16775},
#  {'name': 'LINK/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 12.7155,
#   'bid': 12.7455,
#   'ask': 12.773,
#   'price': 12.7455,
#   'type': 'spot',
#   'baseCurrency': 'LINK',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.03198251082952107,
#   'change24h': -0.0876194566734672,
#   'changeBod': -0.04549539429341721,
#   'quoteVolume24h': 317091.17365,
#   'volumeUsd24h': 317280.92735013564},
#  {'name': 'LTC/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.00276625,
#   'bid': 0.00275175,
#   'ask': 0.00275775,
#   'price': 0.00275775,
#   'type': 'spot',
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.010164835164835165,
#   'change24h': -0.041032774058941145,
#   'changeBod': -0.02518557794273595,
#   'quoteVolume24h': 2.8805672325,
#   'volumeUsd24h': 105489.75497502445},
#  {'name': 'LTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 100.785,
#   'bid': 100.85,
#   'ask': 101.0,
#   'price': 100.85,
#   'type': 'spot',
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.027770700636942675,
#   'change24h': -0.07375091844232182,
#   'changeBod': -0.04375859289811786,
#   'quoteVolume24h': 5036946.391,
#   'volumeUsd24h': 5036946.391},
#  {'name': 'LTC/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 100.49,
#   'bid': 100.78,
#   'ask': 100.97,
#   'price': 100.78,
#   'type': 'spot',
#   'baseCurrency': 'LTC',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.027580932959469794,
#   'change24h': -0.07358551270855357,
#   'changeBod': -0.043878373891181634,
#   'quoteVolume24h': 3176422.30305,
#   'volumeUsd24h': 3178323.137684591},
#  {'name': 'MATIC/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 3.833e-05,
#   'bid': 3.831e-05,
#   'ask': 3.839e-05,
#   'price': 3.833e-05,
#   'type': 'spot',
#   'baseCurrency': 'MATIC',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.015095338983050847,
#   'change24h': -0.052176063303659745,
#   'changeBod': -0.009816584861792819,
#   'quoteVolume24h': 3.510346,
#   'volumeUsd24h': 128552.99304928033},
#  {'name': 'MATIC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 1.402482,
#   'bid': 1.405339,
#   'ask': 1.407202,
#   'price': 1.405339,
#   'type': 'spot',
#   'baseCurrency': 'MATIC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.034355884212470954,
#   'change24h': -0.08089808277769966,
#   'changeBod': -0.02726058905409549,
#   'quoteVolume24h': 11661653.76139,
#   'volumeUsd24h': 11661653.76139},
#  {'name': 'MKR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1816.5,
#   'bid': 1816.0,
#   'ask': 1824.5,
#   'price': 1816.5,
#   'type': 'spot',
#   'baseCurrency': 'MKR',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.020792357403765102,
#   'change24h': 0.011414253897550112,
#   'changeBod': 0.04788001153735218,
#   'quoteVolume24h': 126562.382,
#   'volumeUsd24h': 126562.382},
#  {'name': 'PAXG/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 1968.1,
#   'bid': 1934.3,
#   'ask': 1944.7,
#   'price': 1944.7,
#   'type': 'spot',
#   'baseCurrency': 'PAXG',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': -0.011387321437649332,
#   'change24h': 0.01582741328875888,
#   'changeBod': 0.011810613943808532,
#   'quoteVolume24h': 689707.34653,
#   'volumeUsd24h': 689707.34653},
#  {'name': 'PAXG/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 1955.9,
#   'bid': 1941.9,
#   'ask': 1946.4,
#   'price': 1946.4,
#   'type': 'spot',
#   'baseCurrency': 'PAXG',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': -0.00561969960151221,
#   'change24h': 0.015124647960780222,
#   'changeBod': 0.014754183827746207,
#   'quoteVolume24h': 20390.04716,
#   'volumeUsd24h': 20402.248972021487},
#  {'name': 'SHIB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 100000.0,
#   'minProvideSize': 100000.0,
#   'last': 2.328e-05,
#   'bid': 2.333e-05,
#   'ask': 2.341e-05,
#   'price': 2.333e-05,
#   'type': 'spot',
#   'baseCurrency': 'SHIB',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.028659611992945325,
#   'change24h': -0.11056042699199391,
#   'changeBod': -0.06380417335473515,
#   'quoteVolume24h': 154319.513,
#   'volumeUsd24h': 154319.513},
#  {'name': 'SOL/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 0.00239275,
#   'bid': 0.00238675,
#   'ask': 0.0023905,
#   'price': 0.0023905,
#   'type': 'spot',
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.018859882791688865,
#   'change24h': 0.02092675635276532,
#   'changeBod': 0.049731035239872656,
#   'quoteVolume24h': 141.4805701375,
#   'volumeUsd24h': 5181184.632367936},
#  {'name': 'SOL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 87.6125,
#   'bid': 87.4675,
#   'ask': 87.5775,
#   'price': 87.5775,
#   'type': 'spot',
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.03700304905124182,
#   'change24h': -0.010954572404641576,
#   'changeBod': 0.03029322666980383,
#   'quoteVolume24h': 35110008.177125,
#   'volumeUsd24h': 35110008.177125},
#  {'name': 'SOL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 86.7675,
#   'bid': 87.3775,
#   'ask': 87.5325,
#   'price': 87.3775,
#   'type': 'spot',
#   'baseCurrency': 'SOL',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.03589211618257261,
#   'change24h': -0.012823047592148001,
#   'changeBod': 0.028605903646369817,
#   'quoteVolume24h': 4450840.2812,
#   'volumeUsd24h': 4453503.753041076},
#  {'name': 'SUSHI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 8.405e-05,
#   'bid': 8.388e-05,
#   'ask': 8.404e-05,
#   'price': 8.404e-05,
#   'type': 'spot',
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.016940948693126814,
#   'change24h': -0.07749725576289791,
#   'changeBod': -0.04380475594493116,
#   'quoteVolume24h': 3.15889978,
#   'volumeUsd24h': 115682.61973654824},
#  {'name': 'SUSHI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 3.0731,
#   'bid': 3.0742,
#   'ask': 3.077,
#   'price': 3.0742,
#   'type': 'spot',
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.03344875113456819,
#   'change24h': -0.10890170729586365,
#   'changeBod': -0.06262958897426515,
#   'quoteVolume24h': 879296.4291,
#   'volumeUsd24h': 879296.4291},
#  {'name': 'SUSHI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.5,
#   'minProvideSize': 0.5,
#   'last': 3.0777,
#   'bid': 3.0728,
#   'ask': 3.076,
#   'price': 3.076,
#   'type': 'spot',
#   'baseCurrency': 'SUSHI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.03419291934236627,
#   'change24h': -0.1074744661095636,
#   'changeBod': -0.06139387281825949,
#   'quoteVolume24h': 315535.11355,
#   'volumeUsd24h': 315723.9360726506},
#  {'name': 'TRX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0594825,
#   'bid': 0.05956,
#   'ask': 0.05961,
#   'price': 0.05956,
#   'type': 'spot',
#   'baseCurrency': 'TRX',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1500.0,
#   'change1h': 0.013312917357832504,
#   'change24h': -0.04761143314011593,
#   'changeBod': -0.02071686945083854,
#   'quoteVolume24h': 355041.8309425,
#   'volumeUsd24h': 355041.8309425},
#  {'name': 'TRX/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.0594125,
#   'bid': 0.0594975,
#   'ask': 0.0596525,
#   'price': 0.0594975,
#   'type': 'spot',
#   'baseCurrency': 'TRX',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1500.0,
#   'change1h': 0.013370236321055993,
#   'change24h': -0.04899100899100899,
#   'changeBod': -0.02142269736842105,
#   'quoteVolume24h': 367948.51629,
#   'volumeUsd24h': 368168.70404111827},
#  {'name': 'UNI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 0.05,
#   'minProvideSize': 0.05,
#   'last': 0.0002334,
#   'bid': 0.0002323,
#   'ask': 0.0002328,
#   'price': 0.0002328,
#   'type': 'spot',
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.009321482766095816,
#   'change24h': -0.03781773093614383,
#   'changeBod': -0.005765534913516977,
#   'quoteVolume24h': 1.162592975,
#   'volumeUsd24h': 42575.520086714285},
#  {'name': 'UNI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 8.507,
#   'bid': 8.513,
#   'ask': 8.525,
#   'price': 8.513,
#   'type': 'spot',
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.02516859344894027,
#   'change24h': -0.07043022493994322,
#   'changeBod': -0.02407428636936834,
#   'quoteVolume24h': 420085.2701,
#   'volumeUsd24h': 420085.2701},
#  {'name': 'UNI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.05,
#   'minProvideSize': 0.05,
#   'last': 8.507,
#   'bid': 8.509,
#   'ask': 8.527,
#   'price': 8.509,
#   'type': 'spot',
#   'baseCurrency': 'UNI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.02407028523288001,
#   'change24h': -0.07086700152871805,
#   'changeBod': -0.02374942634235888,
#   'quoteVolume24h': 129963.10645,
#   'volumeUsd24h': 130040.87897216181},
#  {'name': 'USDT/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 1.0006,
#   'bid': 1.0005,
#   'ask': 1.0006,
#   'price': 1.0006,
#   'type': 'spot',
#   'baseCurrency': 'USDT',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 5000.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 9.995002498750625e-05,
#   'quoteVolume24h': 711894.857416,
#   'volumeUsd24h': 711894.857416},
#  {'name': 'WBTC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 0.0001,
#   'minProvideSize': 0.0001,
#   'last': 36775.0,
#   'bid': 36622.0,
#   'ask': 36682.0,
#   'price': 36682.0,
#   'type': 'spot',
#   'baseCurrency': 'WBTC',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 500.0,
#   'change1h': 0.019142611063262302,
#   'change24h': -0.030935460861754683,
#   'changeBod': -0.016357395688083236,
#   'quoteVolume24h': 488939.8482,
#   'volumeUsd24h': 488939.8482},
#  {'name': 'YFI/BTC',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.00025,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 0.52375,
#   'bid': 0.51675,
#   'ask': 0.52,
#   'price': 0.52,
#   'type': 'spot',
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'BTC',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.005802707930367505,
#   'change24h': -0.047182775996335316,
#   'changeBod': -0.04674610449129239,
#   'quoteVolume24h': 0.04439,
#   'volumeUsd24h': 1625.61393134966},
#  {'name': 'YFI/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 18965.0,
#   'bid': 18930.0,
#   'ask': 19000.0,
#   'price': 18965.0,
#   'type': 'spot',
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.022371967654986523,
#   'change24h': -0.08226469876602951,
#   'changeBod': -0.06874539651362632,
#   'quoteVolume24h': 156423.325,
#   'volumeUsd24h': 156423.325},
#  {'name': 'YFI/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5.0,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 19180.0,
#   'bid': 18915.0,
#   'ask': 19025.0,
#   'price': 19025.0,
#   'type': 'spot',
#   'baseCurrency': 'YFI',
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': 0.023675006725854184,
#   'change24h': -0.08025138989605994,
#   'changeBod': -0.06785889269965703,
#   'quoteVolume24h': 76121.115,
#   'volumeUsd24h': 76166.6673976383}]

# %% [markdown]
# Since JSON format isn't that easy to read, let's convert it into a pandas dataframe.

# %%
df = pd.DataFrame(data)
df = df.set_index('name')
# using iloc to make it readable
df.iloc[:,:4].head()
# Out:
#            enabled  postOnly  priceIncrement  sizeIncrement
# name
# AAVE/USD      True     False    1.000000e-02           0.01
# AAVE/USDT     True     False    1.000000e-02           0.01
# AUD/USD       True     False    1.000000e-04           1.00
# AVAX/BTC      True     False    1.000000e-07           0.10
# AVAX/USD      True     False    5.000000e-04           0.10

# %% [markdown]
# Pretty easy, right? This will become second nature soon enough.

# %% [markdown]
# ### Get an Individual Market Data

# %% [markdown]
# You can use the following to get a single market.

# %%
# GET /markets/{market_name}
market_name = 'ETH/USD'
path = f'/markets/{market_name}'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD'

# %% [markdown]
# Now let's make the request and output the response as a dataframe.

# %%
res = requests.get(url).json()
df = pd.DataFrame(res)['result']
df
# Out:
# ask                             2544.2
# baseCurrency                       ETH
# bid                             2542.9
# change1h                      0.038751
# change24h                     -0.04217
# changeBod                    -0.012998
# enabled                           True
# highLeverageFeeExempt             True
# largeOrderThreshold             5000.0
# last                            2543.9
# minProvideSize                   0.001
# name                           ETH/USD
# postOnly                         False
# price                           2543.9
# priceIncrement                     0.1
# quoteCurrency                      USD
# quoteVolume24h           65957059.6477
# restricted                       False
# sizeIncrement                    0.001
# type                              spot
# underlying                        None
# volumeUsd24h             65957059.6477
# Name: result, dtype: object

# %% [markdown]
# ### Get Historical Data

# %% [markdown]
# You can also get historical data for any of the markets. Let's get the data as daily bars starting from 2022.

# %%
# GET /markets/{market_name}/candles?resolution={resolution}&start_time={start_time}&end_time={end_time}

# %%
# Days is 60 seconds * 60 minutes * 24
resolution = 60*60*24
resolution
# Out:
# 86400

# %%
start = datetime.datetime(2022,1,1).timestamp()
start
# Out:
# 1641013200.0

# %% [markdown]
# We'll now construct the URL string and request as we've done above.

# %%
path = f'/markets/{market_name}/candles?resolution={resolution}&start={start}'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/candles?resolution=86400&start=1641013200.0'

# %% [markdown]
# And we'll put the data into the dataframe and clean up the index.

# %%
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df['date'] = pd.to_datetime(df['startTime'])
df = df.set_index('date')
df = df.drop(columns=['startTime', 'time'])
df.head()
# Out:
#                               open     high      low    close  volume
# date
# 2020-03-23 00:00:00+00:00  130.355  136.935  129.625  136.775     0.0
# 2020-03-24 00:00:00+00:00  136.770  144.210  132.855  138.790     0.0
# 2020-03-25 00:00:00+00:00  138.785  142.980  132.750  136.115     0.0
# 2020-03-26 00:00:00+00:00  136.105  140.125  133.615  138.890     0.0
# 2020-03-27 00:00:00+00:00  138.890  141.955  129.320  131.425     0.0

# %% [markdown]
# ## Get Order Book Data

# %% [markdown]
# We can also get the order book at varying depths.

# %% [markdown]
# | Name        | Type   | Value    | Description                   |
# | ----------- | ------ | -------- | ----------------------------- |
# | market_name | string | BTC-0628 | Required. Name of the market. |
# | depth       | number | 35       | max 100, default 20           |

# %% [markdown]
# Let's take a look at the order book for ETH/USD.

# %%
# GET /markets/{market_name}/orderbook?depth={depth}
depth = 20
path =  f'/markets/{market_name}/orderbook?depth={depth}'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/orderbook?depth=20'

# %%
res = requests.get(url).json()
bids = pd.DataFrame(res['result']['bids'])
asks = pd.DataFrame(res['result']['asks'])
bids.columns = ['Bid Price', 'Bid Amount']
asks.columns = ['Ask Price','Ask Amount']
bids.head()
# Out:
#    Bid Price  Bid Amount
# 0     2543.9       5.320
# 1     2543.6       1.520
# 2     2543.2       1.910
# 3     2542.8       1.520
# 4     2542.7      16.531

# %% [markdown]
# Let's merge the two dataframes on their range indices.

# %%
df = pd.merge(bids, asks, left_index=True, right_index=True)
df.head()
# Out:
#    Bid Price  Bid Amount  Ask Price  Ask Amount
# 0     2543.9       5.320     2544.2       0.001
# 1     2543.6       1.520     2545.0       1.520
# 2     2543.2       1.910     2545.3      21.176
# 3     2542.8       1.520     2545.6       1.520
# 4     2542.7      16.531     2545.7       0.120

# %% [markdown]
# And we can get the summary statistics using describe. Notice the depth as the count variable.

# %%
df.describe()
# Out:
#          Bid Price  Bid Amount    Ask Price  Ask Amount
# count    20.000000   20.000000    20.000000   20.000000
# mean   2541.250000   10.443150  2546.810000   11.709000
# std       1.630144   22.722145     1.234973   31.427079
# min    2538.600000    1.480000  2544.200000    0.001000
# 25%    2539.925000    1.520000  2545.850000    1.520000
# 50%    2541.350000    1.520000  2546.950000    1.520000
# 75%    2542.550000    6.026750  2547.825000    3.353000
# max    2543.900000   98.275000  2548.500000  139.181000

# %% [markdown]
# Now let's merge the two dataframes and rename the columns.

# %%
df = pd.merge(bids, asks, left_index=True, right_index=True)
df.head()
# Out:
#    Bid Price  Bid Amount  Ask Price  Ask Amount
# 0     2543.9       5.320     2544.2       0.001
# 1     2543.6       1.520     2545.0       1.520
# 2     2543.2       1.910     2545.3      21.176
# 3     2542.8       1.520     2545.6       1.520
# 4     2542.7      16.531     2545.7       0.120

# %% [markdown]
# ## Get Trades
# Getting the recent trades for any market is also easy.

# %% [markdown]
# | Name        | Type   | Value      | Description        |
# | ----------- | ------ | ---------- | ------------------ |
# | market_name | string | BTC-0628   | name of the market |
# | start_time  | number | 1559881511 | optional           |
# | end_time    | number | 1559881711 | optional           |

# %%
# GET /markets/{market_name}/trades
path = f'/markets/{market_name}/trades'
url = api_url + path
url
# Out:
# 'https://ftx.us/api/markets/ETH/USD/trades'

# %%
res = requests.get(url).json()
df = pd.DataFrame(res['result'])
df.head()
# Out:
#          id   price   size  side  liquidation  \
# 0  25598828  2543.9  1.520  sell        False
# 1  25598812  2542.7  0.001   buy        False
# 2  25598787  2539.0  0.001   buy        False
# 3  25598776  2539.2  0.002  sell        False
# 4  25598764  2537.9  0.002   buy        False
#
#                                time
# 0  2022-02-24T19:20:18.583827+00:00
# 1  2022-02-24T19:20:14.499667+00:00
# 2  2022-02-24T19:19:53.365086+00:00
# 3  2022-02-24T19:19:39.537406+00:00
# 4  2022-02-24T19:19:31.126433+00:00

# %% [markdown]
# ## Working with FTX Futures

# %% [markdown]
# Now that you've learned how to use the Markets API, using the Futures API is just as easy. I'll get you started. One thing to note is that /futures is not available through the ftx.us API.

# %% [markdown]
# First, check out the [futures API documenation](https://docs.ftx.com/#futures). You'll notice we need to make a get request to /futures. Let's create the request URL and use requests to get the data.

# %%
url = 'https://ftx.com/api/futures'
res = requests.get(url).json()
res
# Out:
# {'success': True,
#  'result': [{'name': '1INCH-PERP',
#    'underlying': '1INCH',
#    'description': '1INCH Token Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 1.2989,
#    'bid': 1.2983,
#    'ask': 1.3007,
#    'index': 1.2971271776125,
#    'mark': 1.2983,
#    'imfFactor': 0.0005,
#    'lowerBound': 1.2311,
#    'upperBound': 1.3619,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.2983,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.024946711928633458,
#    'change24h': -0.09576542693968519,
#    'changeBod': -0.061175790006508066,
#    'volumeUsd24h': 9239002.5818,
#    'volume': 7307335.0,
#    'openInterest': 7123256.0,
#    'openInterestUsd': 9248123.2648},
#   {'name': '1INCH-0325',
#    'underlying': '1INCH',
#    'description': '1INCH Token March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 1.263,
#    'bid': 1.2601,
#    'ask': 1.2705,
#    'index': 1.2971271776125,
#    'mark': 1.2586,
#    'imfFactor': 0.0005,
#    'lowerBound': 1.1954,
#    'upperBound': 1.3619,
#    'underlyingDescription': '1INCH Token',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 1.2586,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'change1h': 0.018861814943738363,
#    'change24h': -0.10087155307901129,
#    'changeBod': -0.06611263634339987,
#    'volumeUsd24h': 19980.3395,
#    'volume': 15910.0,
#    'openInterest': 318763.0,
#    'openInterestUsd': 401195.1118},
#   {'name': 'AAPL-0325',
#    'underlying': 'AAPL',
#    'description': 'Apple March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 159.53,
#    'bid': 159.78,
#    'ask': 160.14,
#    'index': 159.48,
#    'mark': 159.56,
#    'imfFactor': 0.005,
#    'lowerBound': 151.51,
#    'upperBound': 167.57,
#    'underlyingDescription': 'Apple',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 159.56,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.00694181496907737,
#    'change24h': -0.01657935285053929,
#    'changeBod': -0.004740518962075849,
#    'volumeUsd24h': 348279.3601,
#    'volume': 2239.98,
#    'openInterest': 2551.41,
#    'openInterestUsd': 407102.9796},
#   {'name': 'AAVE-PERP',
#    'underlying': 'AAVE',
#    'description': 'Aave Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 124.34,
#    'bid': 124.29,
#    'ask': 124.62,
#    'index': 124.11084537706,
#    'mark': 124.14,
#    'imfFactor': 0.0025,
#    'lowerBound': 117.88,
#    'upperBound': 130.31,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 124.14,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'change1h': 0.03320848938826467,
#    'change24h': -0.09775419725270731,
#    'changeBod': -0.04917279411764706,
#    'volumeUsd24h': 24803856.7121,
#    'volume': 205910.63,
#    'openInterest': 115507.09932,
#    'openInterestUsd': 14339051.3095848},
#   {'name': 'AAVE-0325',
#    'underlying': 'AAVE',
#    'description': 'Aave March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 126.03,
#    'bid': 123.93,
#    'ask': 126.02,
#    'index': 124.11084537706,
#    'mark': 125.52,
#    'imfFactor': 0.0025,
#    'lowerBound': 117.91,
#    'upperBound': 131.9,
#    'underlyingDescription': 'Aave',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 125.52,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.04495504495504495,
#    'change24h': -0.08970918848357386,
#    'changeBod': -0.04750341478221278,
#    'volumeUsd24h': 139954.2165,
#    'volume': 1158.06,
#    'openInterest': 1866.05,
#    'openInterestUsd': 234226.596},
#   {'name': 'ABNB-0325',
#    'underlying': 'ABNB',
#    'description': 'Airbnb March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.025,
#    'last': 153.48,
#    'bid': 154.79,
#    'ask': 155.135,
#    'index': 154.315,
#    'mark': 154.78,
#    'imfFactor': 0.005,
#    'lowerBound': 146.6,
#    'upperBound': 162.365,
#    'underlyingDescription': 'Airbnb',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 154.78,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.014584903805185016,
#    'change24h': 0.01170011111837375,
#    'changeBod': 0.031660334599746716,
#    'volumeUsd24h': 23827.995125,
#    'volume': 157.575,
#    'openInterest': 135.275,
#    'openInterestUsd': 20937.8645},
#   {'name': 'ACB-0325',
#    'underlying': 'ACB',
#    'description': 'Aurora Cannabis Inc March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 3.783,
#    'bid': 3.755,
#    'ask': 3.768,
#    'index': 3.753,
#    'mark': 3.768,
#    'imfFactor': 0.0025,
#    'lowerBound': 3.566,
#    'upperBound': 3.957,
#    'underlyingDescription': 'Aurora Cannabis Inc',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 3.768,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.014812819822246161,
#    'change24h': -0.015159435441714584,
#    'changeBod': -0.033846153846153845,
#    'volumeUsd24h': 523076.0732,
#    'volume': 133961.1,
#    'openInterest': 3380.0,
#    'openInterestUsd': 12735.84},
#   {'name': 'ADA-PERP',
#    'underlying': 'ADA',
#    'description': 'Cardano Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.835055,
#    'bid': 0.83426,
#    'ask': 0.835475,
#    'index': 0.831404605097567,
#    'mark': 0.833565,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.78978,
#    'upperBound': 0.87297,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.833565,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'change1h': 0.033135852657932896,
#    'change24h': -0.09271836734693878,
#    'changeBod': -0.037086880682015086,
#    'volumeUsd24h': 257560115.831125,
#    'volume': 316452730.0,
#    'openInterest': 92771486.0,
#    'openInterestUsd': 77331063.72759},
#   {'name': 'ADA-0325',
#    'underlying': 'ADA',
#    'description': 'Cardano March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-06,
#    'sizeIncrement': 1.0,
#    'last': 0.82835,
#    'bid': 0.829295,
#    'ask': 0.83141,
#    'index': 0.831404605097567,
#    'mark': 0.826695,
#    'imfFactor': 4e-05,
#    'lowerBound': 0.785495,
#    'upperBound': 0.87297,
#    'underlyingDescription': 'Cardano',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 0.826695,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'change1h': 0.027626884781284573,
#    'change24h': -0.09655756516037375,
#    'changeBod': -0.04267847837415321,
#    'volumeUsd24h': 8527684.89072,
#    'volume': 10527899.0,
#    'openInterest': 6078166.0,
#    'openInterestUsd': 5024789.44137},
#   {'name': 'AGLD-PERP',
#    'underlying': 'AGLD',
#    'description': 'Adventure Gold Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 1.0805,
#    'bid': 1.079,
#    'ask': 1.0815,
#    'index': 1.0737162227333332,
#    'mark': 1.0785,
#    'imfFactor': 0.001,
#    'lowerBound': 1.0205,
#    'upperBound': 1.1275,
#    'underlyingDescription': 'Adventure Gold',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.0785,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.025190114068441065,
#    'change24h': 0.10502049180327869,
#    'changeBod': 0.1473404255319149,
#    'volumeUsd24h': 10506819.4336,
#    'volume': 10800642.6,
#    'openInterest': 1598150.8,
#    'openInterestUsd': 1723605.6378},
#   {'name': 'ALCX-PERP',
#    'underlying': 'ALCX',
#    'description': 'Alchemix Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 120.6,
#    'bid': 120.6,
#    'ask': 121.1,
#    'index': 120.4,
#    'mark': 120.2,
#    'imfFactor': 0.025,
#    'lowerBound': 114.2,
#    'upperBound': 126.4,
#    'underlyingDescription': 'Alchemix',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 120.2,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.029991431019708654,
#    'change24h': -0.11487481590574374,
#    'changeBod': -0.07538461538461538,
#    'volumeUsd24h': 2247833.5053,
#    'volume': 19268.399,
#    'openInterest': 13001.064,
#    'openInterestUsd': 1562727.8928},
#   {'name': 'ALGO-PERP',
#    'underlying': 'ALGO',
#    'description': 'Algorand Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.7635,
#    'bid': 0.7632,
#    'ask': 0.7649,
#    'index': 0.7623794400047189,
#    'mark': 0.7628,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.7237,
#    'upperBound': 0.8004,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.7628,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'change1h': 0.021014589747021816,
#    'change24h': -0.06759564845373427,
#    'changeBod': -0.028898790579248886,
#    'volumeUsd24h': 28446937.3212,
#    'volume': 38428172.0,
#    'openInterest': 29226575.0,
#    'openInterestUsd': 22294031.41},
#   {'name': 'ALGO-0325',
#    'underlying': 'ALGO',
#    'description': 'Algorand March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 1.0,
#    'last': 0.7635,
#    'bid': 0.7604,
#    'ask': 0.7668,
#    'index': 0.7623794400047189,
#    'mark': 0.7604,
#    'imfFactor': 0.00015,
#    'lowerBound': 0.7235,
#    'upperBound': 0.8004,
#    'underlyingDescription': 'Algorand',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 0.7604,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.01725752508361204,
#    'change24h': -0.0727960004877454,
#    'changeBod': -0.03367645189986021,
#    'volumeUsd24h': 305795.803,
#    'volume': 410841.0,
#    'openInterest': 2047871.0,
#    'openInterestUsd': 1557201.1084},
#   {'name': 'ALICE-PERP',
#    'underlying': 'ALICE',
#    'description': 'MyNeighborAlice Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 6.6525,
#    'bid': 6.645,
#    'ask': 6.655,
#    'index': 6.640452334166667,
#    'mark': 6.635,
#    'imfFactor': 0.0025,
#    'lowerBound': 6.2925,
#    'upperBound': 6.97,
#    'underlyingDescription': 'MyNeighborAlice',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 6.635,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.03268482490272374,
#    'change24h': -0.09543285616905249,
#    'changeBod': -0.06811797752808989,
#    'volumeUsd24h': 26563902.356,
#    'volume': 4032470.0,
#    'openInterest': 1044613.1,
#    'openInterestUsd': 6931007.9185},
#   {'name': 'ALPHA-PERP',
#    'underlying': 'ALPHA',
#    'description': 'Alpha Finance Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.2894,
#    'bid': 0.28925,
#    'ask': 0.2898,
#    'index': 0.28879173325231555,
#    'mark': 0.2891,
#    'imfFactor': 0.00025,
#    'lowerBound': 0.27425,
#    'upperBound': 0.3032,
#    'underlyingDescription': 'Alpha Finance',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.2891,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.03029223093371347,
#    'change24h': -0.09670364005624121,
#    'changeBod': -0.06090628552866656,
#    'volumeUsd24h': 3971967.8023,
#    'volume': 13985420.0,
#    'openInterest': 4895087.0,
#    'openInterestUsd': 1415169.6517},
#   {'name': 'ALT-PERP',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 2990.05,
#    'bid': 2989.75,
#    'ask': 2998.0,
#    'index': 2984.360878343093,
#    'mark': 2986.1,
#    'imfFactor': 0.0008,
#    'lowerBound': 2835.15,
#    'upperBound': 3134.25,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 2986.1,
#    'positionLimitWeight': 2.0,
#    'group': 'perpetual',
#    'change1h': 0.027687436546039612,
#    'change24h': -0.06081240466118354,
#    'changeBod': -0.029336713962975606,
#    'volumeUsd24h': 14536177.22235,
#    'volume': 4972.259,
#    'openInterest': 5055.196,
#    'openInterestUsd': 15095320.7756},
#   {'name': 'ALT-0325',
#    'underlying': 'ALT',
#    'description': 'Altcoin Index March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 2945.35,
#    'bid': 2946.15,
#    'ask': 2961.95,
#    'index': 2984.360878343093,
#    'mark': 2947.4,
#    'imfFactor': 0.0008,
#    'lowerBound': 2800.75,
#    'upperBound': 3133.55,
#    'underlyingDescription': 'Altcoin Index',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 2947.4,
#    'positionLimitWeight': 4.0,
#    'group': 'quarterly',
#    'change1h': 0.02725498396765649,
#    'change24h': -0.06375273974778438,
#    'changeBod': -0.03330654815592253,
#    'volumeUsd24h': 103251.60695,
#    'volume': 36.069,
#    'openInterest': 366.317,
#    'openInterestUsd': 1079682.7258},
#   {'name': 'AMC-0325',
#    'underlying': 'AMC',
#    'description': 'AMC Entertainment Holdings March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 16.895,
#    'bid': 16.865,
#    'ask': 17.025,
#    'index': 16.8325,
#    'mark': 16.895,
#    'imfFactor': 0.0025,
#    'lowerBound': 13.4675,
#    'upperBound': 20.305,
#    'underlyingDescription': 'AMC Entertainment Holdings',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 16.895,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'change1h': 0.04905308910276312,
#    'change24h': 0.05643270282945131,
#    'changeBod': 0.06947301788257636,
#    'volumeUsd24h': 65260.073,
#    'volume': 4153.7,
#    'openInterest': 2509.6,
#    'openInterestUsd': 42399.692},
#   {'name': 'AMD-0325',
#    'underlying': 'AMD',
#    'description': 'Advanced Micro Devices March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 112.66,
#    'bid': 113.01,
#    'ask': 113.3,
#    'index': 112.92,
#    'mark': 112.94,
#    'imfFactor': 0.005,
#    'lowerBound': 107.28,
#    'upperBound': 118.7,
#    'underlyingDescription': 'Advanced Micro Devices',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 112.94,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.02654062897654972,
#    'change24h': 0.008572959457045901,
#    'changeBod': 0.03814688850078132,
#    'volumeUsd24h': 732985.5208,
#    'volume': 6697.96,
#    'openInterest': 625.35,
#    'openInterestUsd': 70627.029},
#   {'name': 'AMPL-PERP',
#    'underlying': 'AMPL',
#    'description': 'Ampleforth Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 10.0,
#    'last': 0.898,
#    'bid': 0.898,
#    'ask': 0.8984,
#    'index': 0.8809441574313633,
#    'mark': 0.898,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.8369,
#    'upperBound': 0.9421,
#    'underlyingDescription': 'Ampleforth',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.898,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'change1h': -0.0198646583715346,
#    'change24h': -0.06904416338378602,
#    'changeBod': -0.014378224124684447,
#    'volumeUsd24h': 1585664.917,
#    'volume': 1757600.0,
#    'openInterest': 1447340.0,
#    'openInterestUsd': 1299711.32},
#   {'name': 'AMZN-0325',
#    'underlying': 'AMZN',
#    'description': 'Amazon March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.001,
#    'last': 2991.6,
#    'bid': 2971.8,
#    'ask': 2978.5,
#    'index': 2969.6,
#    'mark': 2978.5,
#    'imfFactor': 0.03,
#    'lowerBound': 2821.2,
#    'upperBound': 3125.4,
#    'underlyingDescription': 'Amazon',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 2978.5,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.01106622763841271,
#    'change24h': 0.009797938703553024,
#    'changeBod': 0.02650261924455473,
#    'volumeUsd24h': 133151.6944,
#    'volume': 46.412,
#    'openInterest': 48.924,
#    'openInterestUsd': 145720.134},
#   {'name': 'AR-PERP',
#    'underlying': 'AR',
#    'description': 'Arweave Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 25.214,
#    'bid': 25.195,
#    'ask': 25.243,
#    'index': 25.10647086417225,
#    'mark': 25.179,
#    'imfFactor': 0.0025,
#    'lowerBound': 23.852,
#    'upperBound': 26.388,
#    'underlyingDescription': 'Arweave',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 25.179,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.027169257128870396,
#    'change24h': -0.06394289750548347,
#    'changeBod': -0.027199320016999574,
#    'volumeUsd24h': 13335463.0218,
#    'volume': 547477.1,
#    'openInterest': 305829.7,
#    'openInterestUsd': 7700486.0163},
#   {'name': 'ARKK-0325',
#    'underlying': 'ARKK',
#    'description': 'ARK Innovation ETF March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 62.39,
#    'bid': 63.47,
#    'ask': 63.62,
#    'index': 63.41,
#    'mark': 63.46,
#    'imfFactor': 0.005,
#    'lowerBound': 60.16,
#    'upperBound': 66.58,
#    'underlyingDescription': 'ARK Innovation ETF',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 63.46,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.01763951250801796,
#    'change24h': 0.022394071209924277,
#    'changeBod': 0.04684922467832398,
#    'volumeUsd24h': 115336.3273,
#    'volume': 1881.03,
#    'openInterest': 4123.97,
#    'openInterestUsd': 261707.1362},
#   {'name': 'ASD-PERP',
#    'underlying': 'ASD',
#    'description': 'AscendEx Token (BTMX) Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 1e-05,
#    'sizeIncrement': 0.1,
#    'last': 0.21746,
#    'bid': 0.21691,
#    'ask': 0.21773,
#    'index': 0.21786,
#    'mark': 0.21746,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.2066,
#    'upperBound': 0.22875,
#    'underlyingDescription': 'AscendEx Token (BTMX)',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.21746,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'change1h': 0.0,
#    'change24h': -0.01903644893540238,
#    'changeBod': -0.016685507574044765,
#    'volumeUsd24h': 67178.320716,
#    'volume': 307763.6,
#    'openInterest': 4976174.9,
#    'openInterestUsd': 1082118.993754},
#   {'name': 'ATLAS-PERP',
#    'underlying': 'ATLAS',
#    'description': 'Atlas Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-07,
#    'sizeIncrement': 10.0,
#    'last': 0.030816,
#    'bid': 0.03083425,
#    'ask': 0.0309615,
#    'index': 0.0309135,
#    'mark': 0.03082325,
#    'imfFactor': 2.5e-05,
#    'lowerBound': 0.0292665,
#    'upperBound': 0.032459,
#    'underlyingDescription': 'Atlas',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.03082325,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.026603273992905793,
#    'change24h': -0.13875073346559,
#    'changeBod': -0.09900541504373689,
#    'volumeUsd24h': 3142805.81595,
#    'volume': 99506970.0,
#    'openInterest': 122540410.0,
#    'openInterestUsd': 3777093.6925325},
#   {'name': 'ATOM-PERP',
#    'underlying': 'ATOM',
#    'description': 'Cosmos Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 23.5805,
#    'bid': 23.5825,
#    'ask': 23.5975,
#    'index': 23.55999911046099,
#    'mark': 23.558,
#    'imfFactor': 0.0005,
#    'lowerBound': 22.37,
#    'upperBound': 24.7375,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 23.558,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'change1h': 0.017316578140519064,
#    'change24h': -0.10756700445117909,
#    'changeBod': -0.06765607994459286,
#    'volumeUsd24h': 125563142.807995,
#    'volume': 5329674.39,
#    'openInterest': 2055028.735,
#    'openInterestUsd': 48412366.93913},
#   {'name': 'ATOM-0325',
#    'underlying': 'ATOM',
#    'description': 'Cosmos March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.01,
#    'last': 23.4215,
#    'bid': 23.392,
#    'ask': 23.5155,
#    'index': 23.55999911046099,
#    'mark': 23.4215,
#    'imfFactor': 0.0005,
#    'lowerBound': 22.2615,
#    'upperBound': 24.7375,
#    'underlyingDescription': 'Cosmos',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 23.4215,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.018171147868802574,
#    'change24h': -0.10766739689494237,
#    'changeBod': -0.06907927423040998,
#    'volumeUsd24h': 491079.962195,
#    'volume': 21150.56,
#    'openInterest': 152772.95,
#    'openInterestUsd': 3578171.648425},
#   {'name': 'AUDIO-PERP',
#    'underlying': 'AUDIO',
#    'description': 'Audius Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 0.7335,
#    'bid': 0.7335,
#    'ask': 0.735,
#    'index': 0.731622080028645,
#    'mark': 0.7345,
#    'imfFactor': 0.001,
#    'lowerBound': 0.6955,
#    'upperBound': 0.768,
#    'underlyingDescription': 'Audius',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.7345,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.03305203938115331,
#    'change24h': -0.1091570648878108,
#    'changeBod': -0.06552162849872774,
#    'volumeUsd24h': 3076395.7776,
#    'volume': 4289272.2,
#    'openInterest': 2899747.4,
#    'openInterestUsd': 2129864.4653},
#   {'name': 'AVAX-PERP',
#    'underlying': 'AVAX',
#    'description': 'Avalanche Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 72.842,
#    'bid': 72.817,
#    'ask': 72.846,
#    'index': 72.60674427100297,
#    'mark': 72.667,
#    'imfFactor': 0.0007,
#    'lowerBound': 68.966,
#    'upperBound': 76.237,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 72.667,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'change1h': 0.03585072414186338,
#    'change24h': -0.06471458909839758,
#    'changeBod': -0.016737930287941113,
#    'volumeUsd24h': 480839203.431,
#    'volume': 6875386.0,
#    'openInterest': 1302626.8,
#    'openInterestUsd': 94657981.6756},
#   {'name': 'AVAX-0325',
#    'underlying': 'AVAX',
#    'description': 'Avalanche March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 71.661,
#    'bid': 72.016,
#    'ask': 72.454,
#    'index': 72.60674427100297,
#    'mark': 71.881,
#    'imfFactor': 0.002,
#    'lowerBound': 68.289,
#    'upperBound': 76.237,
#    'underlyingDescription': 'Avalanche',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 71.881,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.03585376046575303,
#    'change24h': -0.06447582481941823,
#    'changeBod': -0.01945243973972472,
#    'volumeUsd24h': 1288287.5184,
#    'volume': 18444.0,
#    'openInterest': 46079.9,
#    'openInterestUsd': 3312269.2919},
#   {'name': 'AXS-PERP',
#    'underlying': 'AXS',
#    'description': 'Axie Infinity Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 46.384,
#    'bid': 46.398,
#    'ask': 46.422,
#    'index': 46.329119956458335,
#    'mark': 46.338,
#    'imfFactor': 0.001,
#    'lowerBound': 43.951,
#    'upperBound': 48.645,
#    'underlyingDescription': 'Axie Infinity',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 46.338,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.03023700475788163,
#    'change24h': -0.08366785975597699,
#    'changeBod': -0.048696366249230134,
#    'volumeUsd24h': 41229860.8009,
#    'volume': 921447.2,
#    'openInterest': 843109.4,
#    'openInterestUsd': 39068003.3772},
#   {'name': 'BABA-0325',
#    'underlying': 'BABA',
#    'description': 'Alibaba March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.005,
#    'last': 105.4,
#    'bid': 106.25,
#    'ask': 106.5,
#    'index': 106.2,
#    'mark': 106.25,
#    'imfFactor': 0.01,
#    'lowerBound': 100.9,
#    'upperBound': 111.6,
#    'underlyingDescription': 'Alibaba',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 106.25,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.020653218059558116,
#    'change24h': -0.04019873532068654,
#    'changeBod': -0.03759057971014493,
#    'volumeUsd24h': 119324.25925,
#    'volume': 1131.865,
#    'openInterest': 4919.45,
#    'openInterestUsd': 522691.5625},
#   {'name': 'BADGER-PERP',
#    'underlying': 'BADGER',
#    'description': 'Badger Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.01,
#    'last': 7.53,
#    'bid': 7.505,
#    'ask': 7.535,
#    'index': 7.5147291417305,
#    'mark': 7.505,
#    'imfFactor': 0.0025,
#    'lowerBound': 7.14,
#    'upperBound': 7.89,
#    'underlyingDescription': 'Badger',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 7.505,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.030199039121482498,
#    'change24h': -0.1201641266119578,
#    'changeBod': -0.08475609756097562,
#    'volumeUsd24h': 3592157.88145,
#    'volume': 482527.8,
#    'openInterest': 366027.91,
#    'openInterestUsd': 2747039.46455},
#   {'name': 'BAL-PERP',
#    'underlying': 'BAL',
#    'description': 'Balancer Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.01,
#    'last': 11.4625,
#    'bid': 11.4675,
#    'ask': 11.485,
#    'index': 11.454675130325,
#    'mark': 11.45,
#    'imfFactor': 0.0025,
#    'lowerBound': 10.8725,
#    'upperBound': 12.025,
#    'underlyingDescription': 'Balancer',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 11.45,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'change1h': 0.030835021381949133,
#    'change24h': -0.0730621331714228,
#    'changeBod': -0.03456998313659359,
#    'volumeUsd24h': 2820432.7114,
#    'volume': 254916.84,
#    'openInterest': 402482.94,
#    'openInterestUsd': 4608429.663},
#   {'name': 'BAL-0325',
#    'underlying': 'BAL',
#    'description': 'Balancer March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.01,
#    'last': 11.08,
#    'bid': 10.93,
#    'ask': 11.2175,
#    'index': 11.454675130325,
#    'mark': 11.08,
#    'imfFactor': 0.0025,
#    'lowerBound': 10.5175,
#    'upperBound': 12.025,
#    'underlyingDescription': 'Balancer',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 11.08,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.02806773370447692,
#    'change24h': -0.07801123361764094,
#    'changeBod': -0.04214393775664577,
#    'volumeUsd24h': 84741.475125,
#    'volume': 8058.87,
#    'openInterest': 38246.34,
#    'openInterestUsd': 423769.4472},
#   {'name': 'BAND-PERP',
#    'underlying': 'BAND',
#    'description': 'Band Protocol Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 3.445,
#    'bid': 3.445,
#    'ask': 3.449,
#    'index': 3.43873265295,
#    'mark': 3.442,
#    'imfFactor': 0.001,
#    'lowerBound': 3.267,
#    'upperBound': 3.61,
#    'underlyingDescription': 'Band Protocol',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 3.442,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.037997587454764774,
#    'change24h': -0.08917703096057158,
#    'changeBod': -0.06135805835833106,
#    'volumeUsd24h': 5134524.8393,
#    'volume': 1532179.6,
#    'openInterest': 475185.8,
#    'openInterestUsd': 1635589.5236},
#   {'name': 'BAO-PERP',
#    'underlying': 'BAO',
#    'description': 'BaoToken Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-07,
#    'sizeIncrement': 1000.0,
#    'last': 0.0001535,
#    'bid': 0.000153,
#    'ask': 0.00015525,
#    'index': 0.0001543949983625,
#    'mark': 0.0001535,
#    'imfFactor': 2.5e-05,
#    'lowerBound': 0.0001455,
#    'upperBound': 0.000162,
#    'underlyingDescription': 'BaoToken',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.0001535,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.019933554817275746,
#    'change24h': 0.17624521072796934,
#    'changeBod': 0.18076923076923077,
#    'volumeUsd24h': 9983325.04925,
#    'volume': 78994745000.0,
#    'openInterest': 4545897000.0,
#    'openInterestUsd': 697795.1895},
#   {'name': 'BAT-PERP',
#    'underlying': 'BAT',
#    'description': 'Basic Attention Token Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.62985,
#    'bid': 0.62875,
#    'ask': 0.63035,
#    'index': 0.6283803015526982,
#    'mark': 0.628375,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.59645,
#    'upperBound': 0.659775,
#    'underlyingDescription': 'Basic Attention Token',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.628375,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'change1h': 0.02612778117983262,
#    'change24h': -0.08313270591668491,
#    'changeBod': -0.041380625476735315,
#    'volumeUsd24h': 3635075.295125,
#    'volume': 5972401.0,
#    'openInterest': 8109408.0,
#    'openInterestUsd': 5095749.252},
#   {'name': 'BB-0325',
#    'underlying': 'BB',
#    'description': 'BlackBerry March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 6.3275,
#    'bid': 6.4875,
#    'ask': 6.5075,
#    'index': 6.5325,
#    'mark': 6.4875,
#    'imfFactor': 0.0025,
#    'lowerBound': 5.18,
#    'upperBound': 7.8375,
#    'underlyingDescription': 'BlackBerry',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 6.4875,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'change1h': 0.023668639053254437,
#    'change24h': 0.021251475796930343,
#    'changeBod': 0.045106725734997986,
#    'volumeUsd24h': 34440.941,
#    'volume': 5547.0,
#    'openInterest': 849.9,
#    'openInterestUsd': 5513.72625},
#   {'name': 'BCH-PERP',
#    'underlying': 'BCH',
#    'description': 'Bitcoin Cash Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 287.45,
#    'bid': 287.35,
#    'ask': 287.65,
#    'index': 286.53475,
#    'mark': 287.0,
#    'imfFactor': 0.0008,
#    'lowerBound': 272.25,
#    'upperBound': 301.0,
#    'underlyingDescription': 'Bitcoin Cash',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 287.0,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'change1h': 0.0396667270422025,
#    'change24h': -0.031060094530722483,
#    'changeBod': -0.005026867741376321,
#    'volumeUsd24h': 43996190.52305,
#    'volume': 160888.369,
#    'openInterest': 168981.697,
#    'openInterestUsd': 48497747.039},
#   {'name': 'BCH-0325',
#    'underlying': 'BCH',
#    'description': 'Bitcoin Cash March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 286.9,
#    'bid': 286.35,
#    'ask': 287.15,
#    'index': 286.53475,
#    'mark': 285.9,
#    'imfFactor': 0.0008,
#    'lowerBound': 271.35,
#    'upperBound': 300.85,
#    'underlyingDescription': 'Bitcoin Cash',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 285.9,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'change1h': 0.03888081395348837,
#    'change24h': -0.031995937023869984,
#    'changeBod': -0.007463981947578546,
#    'volumeUsd24h': 307869.3164,
#    'volume': 1140.218,
#    'openInterest': 4233.763,
#    'openInterestUsd': 1210432.8417},
#   {'name': 'BILI-0325',
#    'underlying': 'BILI',
#    'description': 'Bilibili Inc March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.05,
#    'last': 30.3,
#    'bid': 30.81,
#    'ask': 31.0,
#    'index': 30.75,
#    'mark': 30.81,
#    'imfFactor': 0.005,
#    'lowerBound': 29.215,
#    'upperBound': 32.325,
#    'underlyingDescription': 'Bilibili Inc',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 30.81,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.016831683168316833,
#    'change24h': 0.003419638495359062,
#    'changeBod': 0.014822134387351778,
#    'volumeUsd24h': 3907.97,
#    'volume': 131.15,
#    'openInterest': 3756.75,
#    'openInterestUsd': 115745.4675},
#   {'name': 'BIT-PERP',
#    'underlying': 'BIT',
#    'description': 'BitDAO Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.00025,
#    'sizeIncrement': 1.0,
#    'last': 1.20975,
#    'bid': 1.20925,
#    'ask': 1.2115,
#    'index': 1.208250737075,
#    'mark': 1.20975,
#    'imfFactor': 0.001,
#    'lowerBound': 1.146,
#    'upperBound': 1.2685,
#    'underlyingDescription': 'BitDAO',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.20975,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.030890498508734553,
#    'change24h': -0.12857914640734738,
#    'changeBod': -0.10521449704142012,
#    'volumeUsd24h': 7647222.25375,
#    'volume': 6443810.0,
#    'openInterest': 886289.0,
#    'openInterestUsd': 1072188.11775},
#   {'name': 'BITO-0325',
#    'underlying': 'BITO',
#    'description': 'ProShares Bitcoin Strategy ETF March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.01,
#    'last': 22.91,
#    'bid': 23.055,
#    'ask': 23.16,
#    'index': 22.935,
#    'mark': 23.055,
#    'imfFactor': 0.005,
#    'lowerBound': 21.79,
#    'upperBound': 24.215,
#    'underlyingDescription': 'ProShares Bitcoin Strategy ETF',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 23.055,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'change1h': 0.015415106804668574,
#    'change24h': -0.03353594634248585,
#    'changeBod': -0.022057264050901377,
#    'volumeUsd24h': 87418.04895,
#    'volume': 3837.02,
#    'openInterest': 336.58,
#    'openInterestUsd': 7759.8519},
#   {'name': 'BITW-0325',
#    'underlying': 'BITW',
#    'description': 'Bitwise 10 Crypto Index Fund March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.005,
#    'sizeIncrement': 0.01,
#    'last': 32.32,
#    'bid': 29.685,
#    'ask': 29.87,
#    'index': 29.995,
#    'mark': 29.87,
#    'imfFactor': 0.005,
#    'lowerBound': 28.375,
#    'upperBound': 31.49,
#    'underlyingDescription': 'Bitwise 10 Crypto Index Fund',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 29.87,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.029112833763996555,
#    'change24h': -0.0005019240421616195,
#    'changeBod': 0.005385392123864019,
#    'volumeUsd24h': 0.0,
#    'volume': 0.0,
#    'openInterest': 5.03,
#    'openInterestUsd': 150.2461},
#   {'name': 'BNB-PERP',
#    'underlying': 'BNB',
#    'description': 'BNB Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 352.48,
#    'bid': 352.35,
#    'ask': 352.68,
#    'index': 352.0025877006686,
#    'mark': 351.9275,
#    'imfFactor': 0.0005,
#    'lowerBound': 334.3925,
#    'upperBound': 369.6025,
#    'underlyingDescription': 'BNB',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 351.9275,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'change1h': 0.021626956767858568,
#    'change24h': -0.06051828963087047,
#    'changeBod': -0.03671896918644833,
#    'volumeUsd24h': 113853237.8525,
#    'volume': 331253.7,
#    'openInterest': 153070.8,
#    'openInterestUsd': 53869823.967},
#   {'name': 'BNB-0325',
#    'underlying': 'BNB',
#    'description': 'BNB March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0025,
#    'sizeIncrement': 0.1,
#    'last': 348.0375,
#    'bid': 348.465,
#    'ask': 349.185,
#    'index': 352.0025877006686,
#    'mark': 348.19,
#    'imfFactor': 0.0005,
#    'lowerBound': 330.5725,
#    'upperBound': 369.6025,
#    'underlyingDescription': 'BNB',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 348.19,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'change1h': 0.021766721199627317,
#    'change24h': -0.06009542383976353,
#    'changeBod': -0.03653230213687334,
#    'volumeUsd24h': 2229720.40275,
#    'volume': 6627.3,
#    'openInterest': 23588.1,
#    'openInterestUsd': 8213140.539},
#   {'name': 'BNT-PERP',
#    'underlying': 'BNT',
#    'description': 'Bancor Network Token Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 2.1175,
#    'bid': 2.1185,
#    'ask': 2.1245,
#    'index': 2.120112158149125,
#    'mark': 2.117,
#    'imfFactor': 0.0025,
#    'lowerBound': 2.0125,
#    'upperBound': 2.226,
#    'underlyingDescription': 'Bancor Network Token',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 2.117,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.03017031630170316,
#    'change24h': -0.05045974433729536,
#    'changeBod': -0.021719038817005546,
#    'volumeUsd24h': 527116.96705,
#    'volume': 258431.7,
#    'openInterest': 417011.7,
#    'openInterestUsd': 882813.7689},
#   {'name': 'BNTX-0325',
#    'underlying': 'BNTX',
#    'description': 'BioNTech March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 150.43,
#    'bid': 150.47,
#    'ask': 150.88,
#    'index': 150.78,
#    'mark': 150.47,
#    'imfFactor': 0.005,
#    'lowerBound': 142.79,
#    'upperBound': 158.31,
#    'underlyingDescription': 'BioNTech',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 150.47,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': -0.0009295531505212137,
#    'change24h': 0.04733068838310016,
#    'changeBod': 0.06444538766270515,
#    'volumeUsd24h': 592030.2012,
#    'volume': 4005.32,
#    'openInterest': 123.04,
#    'openInterestUsd': 18513.8288},
#   {'name': 'BOBA-PERP',
#    'underlying': 'BOBA',
#    'description': 'Boba Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.1,
#    'last': 1.2345,
#    'bid': 1.234,
#    'ask': 1.2345,
#    'index': 1.2325,
#    'mark': 1.2345,
#    'imfFactor': 0.001,
#    'lowerBound': 1.171,
#    'upperBound': 1.294,
#    'underlyingDescription': 'Boba',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1.2345,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.01982651796778191,
#    'change24h': -0.0998906306963179,
#    'changeBod': -0.08385899814471243,
#    'volumeUsd24h': 1349043.76205,
#    'volume': 1078392.9,
#    'openInterest': 2660290.2,
#    'openInterestUsd': 3284128.2519},
#   {'name': 'BOLSONARO2022',
#    'underlying': 'BOLSONARO',
#    'description': 'Bolsonaro 2022',
#    'type': 'prediction',
#    'expiry': '2022-10-05T00:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.001,
#    'sizeIncrement': 0.1,
#    'last': 0.333,
#    'bid': 0.333,
#    'ask': 0.348,
#    'index': 0.333,
#    'mark': 0.333,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.001,
#    'upperBound': 0.833,
#    'underlyingDescription': '',
#    'expiryDescription': 'BOLSONARO',
#    'moveStart': None,
#    'marginPrice': 5.0,
#    'positionLimitWeight': 10.0,
#    'group': 'prediction',
#    'change1h': 0.0,
#    'change24h': 0.0,
#    'changeBod': 0.0,
#    'volumeUsd24h': 36.9963,
#    'volume': 111.1,
#    'openInterest': 310389.1,
#    'openInterestUsd': 103359.5703},
#   {'name': 'BRZ-PERP',
#    'underlying': 'BRZ',
#    'description': 'Brazilian Digital Token Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 1e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.19355,
#    'bid': 0.19354,
#    'ask': 0.19355,
#    'index': 0.1937,
#    'mark': 0.19355,
#    'imfFactor': 2e-06,
#    'lowerBound': 0.18387,
#    'upperBound': 0.20338,
#    'underlyingDescription': 'Brazilian Digital Token',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.19355,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'change1h': 0.0038900414937759337,
#    'change24h': -0.024789640751750896,
#    'changeBod': -0.022918875258720783,
#    'volumeUsd24h': 22997.38084,
#    'volume': 117061.0,
#    'openInterest': 528213.0,
#    'openInterestUsd': 102235.62615},
#   {'name': 'BSV-PERP',
#    'underlying': 'BSV',
#    'description': 'Bitcoin SV Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 80.51,
#    'bid': 80.46,
#    'ask': 80.6,
#    'index': 80.44163871834236,
#    'mark': 80.43,
#    'imfFactor': 0.001,
#    'lowerBound': 76.39,
#    'upperBound': 84.46,
#    'underlyingDescription': 'Bitcoin SV',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 80.43,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'change1h': 0.02211208539839878,
#    'change24h': -0.042727921923351585,
#    'changeBod': -0.020221707881593373,
#    'volumeUsd24h': 10496848.1599,
#    'volume': 134899.05,
#    'openInterest': 127102.7,
#    'openInterestUsd': 10222870.161},
#   {'name': 'BSV-0325',
#    'underlying': 'BSV',
#    'description': 'Bitcoin SV March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 78.88,
#    'bid': 79.16,
#    'ask': 79.59,
#    'index': 80.44163871834236,
#    'mark': 79.16,
#    'imfFactor': 0.001,
#    'lowerBound': 75.13,
#    'upperBound': 84.46,
#    'underlyingDescription': 'Bitcoin SV',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 79.16,
#    'positionLimitWeight': 10.0,
#    'group': 'quarterly',
#    'change1h': 0.019708875434754605,
#    'change24h': -0.045229767217464724,
#    'changeBod': -0.024762843415054824,
#    'volumeUsd24h': 157227.0238,
#    'volume': 2036.69,
#    'openInterest': 32459.97,
#    'openInterestUsd': 2569531.2252},
#   {'name': 'BTC-PERP',
#    'underlying': 'BTC',
#    'description': 'Bitcoin Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
# ...
#    'volumeUsd24h': 20902627.50375,
#    'volume': 2323299.0,
#    'openInterest': 634649.0,
#    'openInterestUsd': 5618230.2725},
#   {'name': 'WAVES-0325',
#    'underlying': 'WAVES',
#    'description': 'Waves March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0005,
#    'sizeIncrement': 0.5,
#    'last': 8.6065,
#    'bid': 8.5605,
#    'ask': 8.636,
#    'index': 8.869278437825246,
#    'mark': 8.6065,
#    'imfFactor': 0.001,
#    'lowerBound': 8.173,
#    'upperBound': 9.3125,
#    'underlyingDescription': 'Waves',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 8.6065,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.02033195020746888,
#    'change24h': -0.08339102188614943,
#    'changeBod': -0.045260413777802426,
#    'volumeUsd24h': 209768.58425,
#    'volume': 23879.0,
#    'openInterest': 30929.5,
#    'openInterestUsd': 266194.74175},
#   {'name': 'WSB-0325',
#    'underlying': 'WSB',
#    'description': 'WallStreetBets March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.001,
#    'last': 844.55,
#    'bid': 910.1,
#    'ask': 917.05,
#    'index': 913.1170806086589,
#    'mark': 910.1,
#    'imfFactor': 0.01,
#    'lowerBound': 728.95,
#    'upperBound': 1095.7,
#    'underlyingDescription': 'WallStreetBets',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 910.1,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'change1h': 0.012854042624227922,
#    'change24h': -0.06474154763128147,
#    'changeBod': -0.03391539727190701,
#    'volumeUsd24h': 2677.2,
#    'volume': 3.0,
#    'openInterest': 3.32,
#    'openInterestUsd': 3021.532},
#   {'name': 'XAUT-PERP',
#    'underlying': 'XAUT',
#    'description': 'Tether Gold Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.01,
#    'last': 1909.0,
#    'bid': 1908.1,
#    'ask': 1909.0,
#    'index': 1912.8069383625,
#    'mark': 1909.0,
#    'imfFactor': 0.002,
#    'lowerBound': 1812.4,
#    'upperBound': 2008.4,
#    'underlyingDescription': 'Tether Gold',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1909.0,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': -0.01694217003965189,
#    'change24h': -0.0036534446764091857,
#    'changeBod': -0.01047066141405764,
#    'volumeUsd24h': 7866220.446,
#    'volume': 4009.72,
#    'openInterest': 2640.71,
#    'openInterestUsd': 5041115.39},
#   {'name': 'XAUT-0325',
#    'underlying': 'XAUT',
#    'description': 'Tether Gold March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.1,
#    'sizeIncrement': 0.01,
#    'last': 1917.5,
#    'bid': 1917.5,
#    'ask': 1933.3,
#    'index': 1912.8069383625,
#    'mark': 1917.5,
#    'imfFactor': 0.002,
#    'lowerBound': 1817.2,
#    'upperBound': 2010.6,
#    'underlyingDescription': 'Tether Gold',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 1917.5,
#    'positionLimitWeight': 40.0,
#    'group': 'quarterly',
#    'change1h': -0.010016004956373586,
#    'change24h': 0.0013054830287206266,
#    'changeBod': -0.00020856144741644508,
#    'volumeUsd24h': 79209.037,
#    'volume': 40.48,
#    'openInterest': 36.46,
#    'openInterestUsd': 69912.05},
#   {'name': 'XEM-PERP',
#    'underlying': 'XEM',
#    'description': 'NEM Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.09035,
#    'bid': 0.09015,
#    'ask': 0.09035,
#    'index': 0.0902165581369898,
#    'mark': 0.0902,
#    'imfFactor': 0.0005,
#    'lowerBound': 0.08565,
#    'upperBound': 0.0947,
#    'underlyingDescription': 'NEM',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.0902,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.018633540372670808,
#    'change24h': -0.07818088911599387,
#    'changeBod': -0.0455026455026455,
#    'volumeUsd24h': 3349411.4378,
#    'volume': 37647914.0,
#    'openInterest': 15176937.0,
#    'openInterestUsd': 1368959.7174},
#   {'name': 'XLM-PERP',
#    'underlying': 'XLM',
#    'description': 'Stellar Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.175675,
#    'bid': 0.17555,
#    'ask': 0.17585,
#    'index': 0.17556120888179985,
#    'mark': 0.1756,
#    'imfFactor': 0.0001,
#    'lowerBound': 0.166725,
#    'upperBound': 0.184325,
#    'underlyingDescription': 'Stellar',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.1756,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.021672727272727274,
#    'change24h': -0.06259175230214867,
#    'changeBod': -0.03397056800990235,
#    'volumeUsd24h': 21832502.214925,
#    'volume': 127332514.0,
#    'openInterest': 82699909.0,
#    'openInterestUsd': 14522104.0204},
#   {'name': 'XMR-PERP',
#    'underlying': 'XMR',
#    'description': 'Monero Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.01,
#    'last': 142.94,
#    'bid': 142.77,
#    'ask': 143.01,
#    'index': 142.88280779903602,
#    'mark': 142.71,
#    'imfFactor': 0.005,
#    'lowerBound': 135.47,
#    'upperBound': 150.02,
#    'underlyingDescription': 'Monero',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 142.71,
#    'positionLimitWeight': 5.0,
#    'group': 'perpetual',
#    'change1h': 0.027577764976958526,
#    'change24h': -0.058206295783013264,
#    'changeBod': -0.040411511565357716,
#    'volumeUsd24h': 4552493.4204,
#    'volume': 32636.76,
#    'openInterest': 39434.94,
#    'openInterestUsd': 5627760.2874},
#   {'name': 'XRP-PERP',
#    'underlying': 'XRP',
#    'description': 'XRP Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.67245,
#    'bid': 0.672525,
#    'ask': 0.6729,
#    'index': 0.671642,
#    'mark': 0.671425,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.6377,
#    'upperBound': 0.7052,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.671425,
#    'positionLimitWeight': 4.0,
#    'group': 'perpetual',
#    'change1h': 0.019705368668843495,
#    'change24h': -0.05817786505821293,
#    'changeBod': -0.03972397025171625,
#    'volumeUsd24h': 189176689.311725,
#    'volume': 287094460.0,
#    'openInterest': 96637795.0,
#    'openInterestUsd': 64885031.507875},
#   {'name': 'XRP-0325',
#    'underlying': 'XRP',
#    'description': 'XRP March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 2.5e-05,
#    'sizeIncrement': 1.0,
#    'last': 0.6718,
#    'bid': 0.6726,
#    'ask': 0.673825,
#    'index': 0.671948,
#    'mark': 0.672175,
#    'imfFactor': 2e-05,
#    'lowerBound': 0.638375,
#    'upperBound': 0.70565,
#    'underlyingDescription': 'XRP',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 0.672175,
#    'positionLimitWeight': 8.0,
#    'group': 'quarterly',
#    'change1h': 0.02006980802792321,
#    'change24h': -0.05732417081551083,
#    'changeBod': -0.038273062202668386,
#    'volumeUsd24h': 2862284.784025,
#    'volume': 4385684.0,
#    'openInterest': 11008487.0,
#    'openInterestUsd': 7399629.749225},
#   {'name': 'XTZ-PERP',
#    'underlying': 'XTZ',
#    'description': 'Tezos Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 2.8757,
#    'bid': 2.8772,
#    'ask': 2.8802,
#    'index': 2.8694076024065787,
#    'mark': 2.8732,
#    'imfFactor': 0.0004,
#    'lowerBound': 2.7222,
#    'upperBound': 3.0128,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 2.8732,
#    'positionLimitWeight': 100.0,
#    'group': 'perpetual',
#    'change1h': 0.02427720936864996,
#    'change24h': -0.07572540693559802,
#    'changeBod': -0.017742983145875354,
#    'volumeUsd24h': 25500312.2483341,
#    'volume': 9307961.636,
#    'openInterest': 3766658.152,
#    'openInterestUsd': 10822362.2023264},
#   {'name': 'XTZ-0325',
#    'underlying': 'XTZ',
#    'description': 'Tezos March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.0001,
#    'sizeIncrement': 0.001,
#    'last': 2.8657,
#    'bid': 2.8712,
#    'ask': 2.8883,
#    'index': 2.8694076024065787,
#    'mark': 2.8713,
#    'imfFactor': 0.0004,
#    'lowerBound': 2.7255,
#    'upperBound': 3.0128,
#    'underlyingDescription': 'Tezos',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 2.8713,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.024512952258616997,
#    'change24h': -0.07929840312960944,
#    'changeBod': -0.021903529091156834,
#    'volumeUsd24h': 612427.8815075,
#    'volume': 212870.767,
#    'openInterest': 709201.981,
#    'openInterestUsd': 2036331.6480453},
#   {'name': 'YFI-PERP',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 18970.0,
#    'bid': 18950.0,
#    'ask': 18980.0,
#    'index': 18942.885224548125,
#    'mark': 18930.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 17990.0,
#    'upperBound': 19890.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 18930.0,
#    'positionLimitWeight': 50.0,
#    'group': 'perpetual',
#    'change1h': 0.02186234817813765,
#    'change24h': -0.08462282398452611,
#    'changeBod': -0.06909269731989182,
#    'volumeUsd24h': 16668654.36,
#    'volume': 909.879,
#    'openInterest': 451.185,
#    'openInterestUsd': 8540932.05},
#   {'name': 'YFI-0325',
#    'underlying': 'YFI',
#    'description': 'Yearn.Finance March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T03:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 5.0,
#    'sizeIncrement': 0.001,
#    'last': 19000.0,
#    'bid': 18345.0,
#    'ask': 19005.0,
#    'index': 18942.885224548125,
#    'mark': 18985.0,
#    'imfFactor': 0.0033,
#    'lowerBound': 18000.0,
#    'upperBound': 19900.0,
#    'underlyingDescription': 'Yearn.Finance',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 18985.0,
#    'positionLimitWeight': 100.0,
#    'group': 'quarterly',
#    'change1h': 0.034604904632152586,
#    'change24h': -0.07345046364080039,
#    'changeBod': -0.05921704658077304,
#    'volumeUsd24h': 26700.11,
#    'volume': 1.468,
#    'openInterest': 6.941,
#    'openInterestUsd': 131774.885},
#   {'name': 'YFII-PERP',
#    'underlying': 'YFII',
#    'description': 'DFI.Money Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.25,
#    'sizeIncrement': 0.001,
#    'last': 1779.75,
#    'bid': 1779.75,
#    'ask': 1785.5,
#    'index': 1780.9530968464167,
#    'mark': 1778.5,
#    'imfFactor': 0.025,
#    'lowerBound': 1689.0,
#    'upperBound': 1870.0,
#    'underlyingDescription': 'DFI.Money',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 1778.5,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.027589195435504837,
#    'change24h': -0.0751430057202288,
#    'changeBod': -0.03825875354873597,
#    'volumeUsd24h': 1385113.656,
#    'volume': 806.74,
#    'openInterest': 612.35,
#    'openInterestUsd': 1089064.475},
#   {'name': 'ZEC-PERP',
#    'underlying': 'ZEC',
#    'description': 'Zcash Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.01,
#    'sizeIncrement': 0.05,
#    'last': 97.25,
#    'bid': 97.32,
#    'ask': 97.42,
#    'index': 97.131874139,
#    'mark': 97.1,
#    'imfFactor': 0.001,
#    'lowerBound': 92.21,
#    'upperBound': 101.98,
#    'underlyingDescription': 'Zcash',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 97.1,
#    'positionLimitWeight': 3.0,
#    'group': 'perpetual',
#    'change1h': 0.03056675864996816,
#    'change24h': -0.050088045392291135,
#    'changeBod': -0.012006512006512007,
#    'volumeUsd24h': 20034782.207,
#    'volume': 218742.35,
#    'openInterest': 91489.4,
#    'openInterestUsd': 8883620.74},
#   {'name': 'ZIL-PERP',
#    'underlying': 'ZIL',
#    'description': 'Zilliqa Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 1e-05,
#    'sizeIncrement': 10.0,
#    'last': 0.03651,
#    'bid': 0.03655,
#    'ask': 0.0366,
#    'index': 0.03651222863925,
#    'mark': 0.03651,
#    'imfFactor': 0.00025,
#    'lowerBound': 0.03467,
#    'upperBound': 0.03833,
#    'underlyingDescription': 'Zilliqa',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.03651,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.02469828795958462,
#    'change24h': -0.09314456035767511,
#    'changeBod': -0.06192189105858171,
#    'volumeUsd24h': 4095573.8428,
#    'volume': 114174780.0,
#    'openInterest': 44183960.0,
#    'openInterestUsd': 1613156.3796},
#   {'name': 'ZM-0325',
#    'underlying': 'ZM',
#    'description': 'Zoom March 2022 Futures',
#    'type': 'future',
#    'expiry': '2022-03-25T20:00:00+00:00',
#    'perpetual': False,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.05,
#    'sizeIncrement': 0.005,
#    'last': 119.2,
#    'bid': 121.95,
#    'ask': 122.3,
#    'index': 121.37,
#    'mark': 121.85,
#    'imfFactor': 0.01,
#    'lowerBound': 115.35,
#    'upperBound': 127.6,
#    'underlyingDescription': 'Zoom',
#    'expiryDescription': 'March 2022',
#    'moveStart': None,
#    'marginPrice': 121.85,
#    'positionLimitWeight': 200.0,
#    'group': 'quarterly',
#    'change1h': 0.022660511959714646,
#    'change24h': -0.006522625356706074,
#    'changeBod': 0.010364842454394693,
#    'volumeUsd24h': 645346.49075,
#    'volume': 5497.865,
#    'openInterest': 710.725,
#    'openInterestUsd': 86601.84125},
#   {'name': 'ZRX-PERP',
#    'underlying': 'ZRX',
#    'description': '0x Perpetual Futures',
#    'type': 'perpetual',
#    'expiry': None,
#    'perpetual': True,
#    'expired': False,
#    'enabled': True,
#    'postOnly': False,
#    'priceIncrement': 0.00025,
#    'sizeIncrement': 1.0,
#    'last': 0.49275,
#    'bid': 0.49225,
#    'ask': 0.493,
#    'index': 0.49176685645833335,
#    'mark': 0.49225,
#    'imfFactor': 0.001,
#    'lowerBound': 0.467,
#    'upperBound': 0.51625,
#    'underlyingDescription': '0x',
#    'expiryDescription': 'Perpetual',
#    'moveStart': None,
#    'marginPrice': 0.49225,
#    'positionLimitWeight': 20.0,
#    'group': 'perpetual',
#    'change1h': 0.029273392577104027,
#    'change24h': -0.09761686526122823,
#    'changeBod': -0.06505223171889839,
#    'volumeUsd24h': 2075368.805,
#    'volume': 4245982.0,
#    'openInterest': 2622429.0,
#    'openInterestUsd': 1290890.67525}]}

# %%
df = pd.DataFrame(res['result'])
# Using iloc to make it readable
df.iloc[:,:4].head()
# Out:
#          name underlying                     description       type
# 0  1INCH-PERP      1INCH   1INCH Token Perpetual Futures  perpetual
# 1  1INCH-0325      1INCH  1INCH Token March 2022 Futures     future
# 2   AAPL-0325       AAPL        Apple March 2022 Futures     future
# 3   AAVE-PERP       AAVE          Aave Perpetual Futures  perpetual
# 4   AAVE-0325       AAVE         Aave March 2022 Futures     future
