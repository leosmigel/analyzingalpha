# %% [markdown]
# # S&P500 Historial Components & Changes

# %% [markdown]
# Let's use web scraping to grab the S&P 500 current and historical components. For those of you that just want the data, see the below download links.

# %%
import datetime as dt
import pandas as pd

# %% [markdown]
# ## 1. Web Scrape Using Pandas

# %%
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
data = pd.read_html(url)
print(f"We have a {type(data)} with length {len(data)}.")
# Out:
# We have a <class 'list'> with length 2.

# %%
data[0].head()
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM                   3M     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV               AbbVie     reports             Health Care
# 3   ABMD              Abiomed     reports             Health Care
# 4    ACN            Accenture     reports  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# 3   815094         1981
# 4  1467373         1989

# %%
data[1].head()
# Out:
#                  Date  Added                Removed                           \
#                  Date Ticker       Security  Ticker                 Security
# 0  September 20, 2021   MTCH    Match Group    PRGO                  Perrigo
# 1  September 20, 2021   CDAY       Ceridian     UNM                     Unum
# 2  September 20, 2021    BRO  Brown & Brown     NOV                      Nov
# 3     August 30, 2021   TECH     Bio-Techne    MXIM         Maxim Integrated
# 4       July 21, 2021   MRNA        Moderna    ALXN  Alexion Pharmaceuticals
#
#                                               Reason
#                                               Reason
# 0                   Market capitalization change.[6]
# 1                   Market capitalization change.[6]
# 2                   Market capitalization change.[6]
# 3  S&P 500 constituent Analog Devices acquired Ma...
# 4  AstraZeneca Plc acquired Alexion Pharmaceutica...

# %% [markdown]
# ## 2. Get Current S&P 500 Members

# %%
sp500 = data[0].iloc[:, [0,1,6,7]]
sp500.columns = ['ticker', 'name', 'date' , 'cik']
sp500.head()
# Out:
#   ticker                 name        date      cik
# 0    MMM                   3M  1976-08-09    66740
# 1    ABT  Abbott Laboratories  1964-03-31     1800
# 2   ABBV               AbbVie  2012-12-31  1551152
# 3   ABMD              Abiomed  2018-05-31   815094
# 4    ACN            Accenture  2011-07-06  1467373

# %%
sp500[sp500['date'].isnull()]
# Out:
#     ticker                      name date      cik
# 7      AMD    Advanced Micro Devices  NaN     2488
# 126     ED       Consolidated Edison  NaN  1047862
# 130    GLW                   Corning  NaN    24741
# 138    DHR       Danaher Corporation  NaN   313616
# 139    DRI        Darden Restaurants  NaN   940944
# 154      D           Dominion Energy  NaN   715957
# 164    ETN         Eaton Corporation  NaN  1551182
# 181     ES         Eversource Energy  NaN    72741
# 194   FITB       Fifth Third Bancorp  NaN    35527
# 195     FE               FirstEnergy  NaN  1031296
# 206    BEN        Franklin Resources  NaN    38777
# 207    FCX          Freeport-McMoRan  NaN   831259
# 213     GE          General Electric  NaN    40545
# 240    HUM                    Humana  NaN    49071
# 241   HBAN     Huntington Bancshares  NaN    49196
# 277   KLAC           KLA Corporation  NaN   319201
# 294      L         Loews Corporation  NaN    60086
# 302    MAR    Marriott International  NaN  1048286
# 310    MCK      McKesson Corporation  NaN   927653
# 313    MET                   MetLife  NaN  1099219
# 326    MCO       Moody's Corporation  NaN  1059556
# 327     MS            Morgan Stanley  NaN   895421
# 329    MSI        Motorola Solutions  NaN    68505
# 341     NI                  NiSource  NaN  1111711
# 343   NTRS            Northern Trust  NaN    73124
# 355    OMC             Omnicom Group  NaN    29989
# 363   PAYX                   Paychex  NaN   723531
# 374    PNW     Pinnacle West Capital  NaN   764622
# 379    PPL                       PPL  NaN   922224
# 392   QCOM                  Qualcomm  NaN   804328
# 396    RTX     Raytheon Technologies  NaN   101829
# 404    ROK       Rockwell Automation  NaN  1024478
# 409   SPGI                S&P Global  NaN    64040
# 415    SRE             Sempra Energy  NaN  1032208
# 424   SBUX                 Starbucks  NaN   829224
# 425    STT  State Street Corporation  NaN    93751
# 433   TROW             T. Rowe Price  NaN  1113169
# 435    TPR                  Tapestry  NaN  1116132
# 442    TXN         Texas Instruments  NaN    97476
# 457    USB              U.S. Bancorp  NaN    36104
# 466    VLO             Valero Energy  NaN  1035002
# 473   VIAC                 ViacomCBS  NaN   813828
# 476    VNO      Vornado Realty Trust  NaN   899689
# 483     WM          Waste Management  NaN   823768
# 484    WAT        Waters Corporation  NaN  1000697
# 491    WRK                  WestRock  NaN  1732845
# 492     WY              Weyerhaeuser  NaN   106535
# 493    WHR     Whirlpool Corporation  NaN   106640

# %%
mask = sp500['date'].str.strip().str.fullmatch('\d{4}-\d{2}-\d{2}')
mask.loc[mask.isnull()] = False
mask = mask == False
sp500[mask]
# Out:
#     ticker                      name                     date      cik
# 7      AMD    Advanced Micro Devices                      NaN     2488
# 51       T                      AT&T  1983-11-30 (1957-03-04)   732717
# 126     ED       Consolidated Edison                      NaN  1047862
# 130    GLW                   Corning                      NaN    24741
# 138    DHR       Danaher Corporation                      NaN   313616
# 139    DRI        Darden Restaurants                      NaN   940944
# 154      D           Dominion Energy                      NaN   715957
# 164    ETN         Eaton Corporation                      NaN  1551182
# 181     ES         Eversource Energy                      NaN    72741
# 194   FITB       Fifth Third Bancorp                      NaN    35527
# 195     FE               FirstEnergy                      NaN  1031296
# 206    BEN        Franklin Resources                      NaN    38777
# 207    FCX          Freeport-McMoRan                      NaN   831259
# 213     GE          General Electric                      NaN    40545
# 240    HUM                    Humana                      NaN    49071
# 241   HBAN     Huntington Bancshares                      NaN    49196
# 277   KLAC           KLA Corporation                      NaN   319201
# 294      L         Loews Corporation                      NaN    60086
# 302    MAR    Marriott International                      NaN  1048286
# 310    MCK      McKesson Corporation                      NaN   927653
# 313    MET                   MetLife                      NaN  1099219
# 326    MCO       Moody's Corporation                      NaN  1059556
# 327     MS            Morgan Stanley                      NaN   895421
# 329    MSI        Motorola Solutions                      NaN    68505
# 341     NI                  NiSource                      NaN  1111711
# 343   NTRS            Northern Trust                      NaN    73124
# 355    OMC             Omnicom Group                      NaN    29989
# 363   PAYX                   Paychex                      NaN   723531
# 374    PNW     Pinnacle West Capital                      NaN   764622
# 379    PPL                       PPL                      NaN   922224
# 392   QCOM                  Qualcomm                      NaN   804328
# 396    RTX     Raytheon Technologies                      NaN   101829
# 404    ROK       Rockwell Automation                      NaN  1024478
# 409   SPGI                S&P Global                      NaN    64040
# 415    SRE             Sempra Energy                      NaN  1032208
# 424   SBUX                 Starbucks                      NaN   829224
# 425    STT  State Street Corporation                      NaN    93751
# 433   TROW             T. Rowe Price                      NaN  1113169
# 435    TPR                  Tapestry                      NaN  1116132
# 442    TXN         Texas Instruments                      NaN    97476
# 457    USB              U.S. Bancorp                      NaN    36104
# 466    VLO             Valero Energy                      NaN  1035002
# 473   VIAC                 ViacomCBS                      NaN   813828
# 476    VNO      Vornado Realty Trust                      NaN   899689
# 483     WM          Waste Management                      NaN   823768
# 484    WAT        Waters Corporation                      NaN  1000697
# 491    WRK                  WestRock                      NaN  1732845
# 492     WY              Weyerhaeuser                      NaN   106535
# 493    WHR     Whirlpool Corporation                      NaN   106640

# %%
current = sp500.copy()
current.loc[mask, 'date'] = '1900-01-01'
current.loc[:, 'date'] = pd.to_datetime(current['date'])
current.loc[:, 'cik'] = current['cik'].apply(str).str.zfill(10)
current.head(10)
# Out:
#   ticker                    name       date         cik
# 0    MMM                      3M 1976-08-09  0000066740
# 1    ABT     Abbott Laboratories 1964-03-31  0000001800
# 2   ABBV                  AbbVie 2012-12-31  0001551152
# 3   ABMD                 Abiomed 2018-05-31  0000815094
# 4    ACN               Accenture 2011-07-06  0001467373
# 5   ATVI     Activision Blizzard 2015-08-31  0000718877
# 6   ADBE                   Adobe 1997-05-05  0000796343
# 7    AMD  Advanced Micro Devices 1900-01-01  0000002488
# 8    AAP      Advance Auto Parts 2015-07-09  0001158449
# 9    AES                AES Corp 1998-10-02  0000874761

# %% [markdown]
# ## 3. Manage Adjustments

# %%
adjustments = data[1]
adjustments
# Out:
#                    Date  Added                      Removed  \
#                    Date Ticker             Security  Ticker
# 0    September 20, 2021   MTCH          Match Group    PRGO
# 1    September 20, 2021   CDAY             Ceridian     UNM
# 2    September 20, 2021    BRO        Brown & Brown     NOV
# 3       August 30, 2021   TECH           Bio-Techne    MXIM
# 4         July 21, 2021   MRNA              Moderna    ALXN
# ..                  ...    ...                  ...     ...
# 276    December 5, 2000    SBL  Symbol Technologies      OI
# 277    December 5, 2000    AYE     Allegheny Energy     GRA
# 278    December 5, 2000    ABK      Ambac Financial     CCK
# 279       July 27, 2000   JDSU         JDS Uniphase     RAD
# 280    December 7, 1999   YHOO               Yahoo!     LDW
#
#                               \
#                     Security
# 0                    Perrigo
# 1                       Unum
# 2                        Nov
# 3           Maxim Integrated
# 4    Alexion Pharmaceuticals
# ..                       ...
# 276           Owens-Illinois
# 277                 WR Grace
# 278           Crown Holdings
# 279                  RiteAid
# 280                  Laidlaw
#
#                                                 Reason
#                                                 Reason
# 0                     Market capitalization change.[6]
# 1                     Market capitalization change.[6]
# 2                     Market capitalization change.[6]
# 3    S&P 500 constituent Analog Devices acquired Ma...
# 4    AstraZeneca Plc acquired Alexion Pharmaceutica...
# ..                                                 ...
# 276                                Market Cap changes.
# 277                                Market Cap changes.
# 278                                Market Cap changes.
# 279                            Market Cap change.[219]
# 280                 Market capitalization change.[220]
#
# [281 rows x 6 columns]

# %%
columns = ['date', 'ticker_added', 'name_added', 'ticker_removed', 'name_removed', 'reason']
adjustments.columns = columns
adjustments
# Out:
#                    date ticker_added           name_added ticker_removed  \
# 0    September 20, 2021         MTCH          Match Group           PRGO
# 1    September 20, 2021         CDAY             Ceridian            UNM
# 2    September 20, 2021          BRO        Brown & Brown            NOV
# 3       August 30, 2021         TECH           Bio-Techne           MXIM
# 4         July 21, 2021         MRNA              Moderna           ALXN
# ..                  ...          ...                  ...            ...
# 276    December 5, 2000          SBL  Symbol Technologies             OI
# 277    December 5, 2000          AYE     Allegheny Energy            GRA
# 278    December 5, 2000          ABK      Ambac Financial            CCK
# 279       July 27, 2000         JDSU         JDS Uniphase            RAD
# 280    December 7, 1999         YHOO               Yahoo!            LDW
#
#                 name_removed  \
# 0                    Perrigo
# 1                       Unum
# 2                        Nov
# 3           Maxim Integrated
# 4    Alexion Pharmaceuticals
# ..                       ...
# 276           Owens-Illinois
# 277                 WR Grace
# 278           Crown Holdings
# 279                  RiteAid
# 280                  Laidlaw
#
#                                                 reason
# 0                     Market capitalization change.[6]
# 1                     Market capitalization change.[6]
# 2                     Market capitalization change.[6]
# 3    S&P 500 constituent Analog Devices acquired Ma...
# 4    AstraZeneca Plc acquired Alexion Pharmaceutica...
# ..                                                 ...
# 276                                Market Cap changes.
# 277                                Market Cap changes.
# 278                                Market Cap changes.
# 279                            Market Cap change.[219]
# 280                 Market capitalization change.[220]
#
# [281 rows x 6 columns]

# %%
adjustments.isnull().sum()
# Out:
# date               0
# ticker_added       5
# name_added         5
# ticker_removed    10
# name_removed      10
# reason             0
# dtype: int64

# %%
adjustments[adjustments['ticker_removed'].isnull()]
# Out:
#                    date ticker_added                        name_added  \
# 6          June 3, 2021          OGN                     Organon & Co.
# 18      October 9, 2020          VNT                           Vontier
# 31        April 3, 2020         OTIS                    Otis Worldwide
# 32        April 3, 2020         CARR                    Carrier Global
# 126       April 8, 2016           UA            Under Armour (Class C)
# 144  September 18, 2015        CMCSK           Comcast Class K Special
# 145  September 18, 2015          FOX  Twenty-First Century Fox Class B
# 146  September 18, 2015          NWS          News Corporation Class B
# 171      August 6, 2014        DISCK          Discovery Communications
# 178       April 3, 2014        GOOGL                            Google
#
#     ticker_removed name_removed  \
# 6              NaN          NaN
# 18             NaN          NaN
# 31             NaN          NaN
# 32             NaN          NaN
# 126            NaN          NaN
# 144            NaN          NaN
# 145            NaN          NaN
# 146            NaN          NaN
# 171            NaN          NaN
# 178            NaN          NaN
#
#                                                 reason
# 6    S&P 500/100 constituent Merck & Co. spun off O...
# 18   S&P 500 constituent Fortive spun off Vontier.[17]
# 31   United Technologies spun off Otis and Carrier ...
# 32   United Technologies spun off Otis and Carrier ...
# 126  Under Armour distribution of second class of s...
# 144                Share class methodology change[112]
# 145                     Share class methodology change
# 146                     Share class methodology change
# 171                    Class C share distribution[133]
# 178             Google Class C share distribution[139]

# %%
additions = adjustments[~adjustments['ticker_added'].isnull()][['date','ticker_added', 'name_added']]
additions.columns = ['date','ticker','name']
additions['action'] = 'added'
additions
# Out:
#                    date ticker                 name action
# 0    September 20, 2021   MTCH          Match Group  added
# 1    September 20, 2021   CDAY             Ceridian  added
# 2    September 20, 2021    BRO        Brown & Brown  added
# 3       August 30, 2021   TECH           Bio-Techne  added
# 4         July 21, 2021   MRNA              Moderna  added
# ..                  ...    ...                  ...    ...
# 276    December 5, 2000    SBL  Symbol Technologies  added
# 277    December 5, 2000    AYE     Allegheny Energy  added
# 278    December 5, 2000    ABK      Ambac Financial  added
# 279       July 27, 2000   JDSU         JDS Uniphase  added
# 280    December 7, 1999   YHOO               Yahoo!  added
#
# [276 rows x 4 columns]

# %%
removals = adjustments[~adjustments['ticker_removed'].isnull()][['date','ticker_removed','name_removed']]
removals.columns = ['date','ticker','name']
removals['action'] = 'removed'
removals
# Out:
#                    date ticker                     name   action
# 0    September 20, 2021   PRGO                  Perrigo  removed
# 1    September 20, 2021    UNM                     Unum  removed
# 2    September 20, 2021    NOV                      Nov  removed
# 3       August 30, 2021   MXIM         Maxim Integrated  removed
# 4         July 21, 2021   ALXN  Alexion Pharmaceuticals  removed
# ..                  ...    ...                      ...      ...
# 276    December 5, 2000     OI           Owens-Illinois  removed
# 277    December 5, 2000    GRA                 WR Grace  removed
# 278    December 5, 2000    CCK           Crown Holdings  removed
# 279       July 27, 2000    RAD                  RiteAid  removed
# 280    December 7, 1999    LDW                  Laidlaw  removed
#
# [271 rows x 4 columns]

# %%
historical = pd.concat([additions, removals])
historical
# Out:
#                    date ticker            name   action
# 0    September 20, 2021   MTCH     Match Group    added
# 1    September 20, 2021   CDAY        Ceridian    added
# 2    September 20, 2021    BRO   Brown & Brown    added
# 3       August 30, 2021   TECH      Bio-Techne    added
# 4         July 21, 2021   MRNA         Moderna    added
# ..                  ...    ...             ...      ...
# 276    December 5, 2000     OI  Owens-Illinois  removed
# 277    December 5, 2000    GRA        WR Grace  removed
# 278    December 5, 2000    CCK  Crown Holdings  removed
# 279       July 27, 2000    RAD         RiteAid  removed
# 280    December 7, 1999    LDW         Laidlaw  removed
#
# [547 rows x 4 columns]

# %% [markdown]
# ## 4. Merge Missing Tickers

# %%
missing = current[~current['ticker'].isin(historical['ticker'])].copy()
missing
# Out:
#     ticker                 name       date       cik
# 0      MMM                   3M 1976-08-09  00066740
# 1      ABT  Abbott Laboratories 1964-03-31  00001800
# 6     ADBE                Adobe 1997-05-05  00796343
# 9      AES             AES Corp 1998-10-02  00874761
# 10     AFL                Aflac 1999-05-28  00004977
# ..     ...                  ...        ...       ...
# 497    XEL          Xcel Energy 1957-03-04  00072903
# 498   XLNX               Xilinx 1999-11-08  00743988
# 500    YUM          Yum! Brands 1997-10-06  01041061
# 502    ZBH        Zimmer Biomet 2001-08-07  01136869
# 503   ZION        Zions Bancorp 2001-06-22  00109380
#
# [302 rows x 4 columns]

# %%
missing['action'] = 'added'
missing = missing[['date','ticker','name','action', 'cik']]
missing
# Out:
#            date ticker                 name action      cik
# 0    1976-08-09    MMM                   3M  added    66740
# 1    1964-03-31    ABT  Abbott Laboratories  added     1800
# 6    1997-05-05   ADBE                Adobe  added   796343
# 9    1998-10-02    AES             AES Corp  added   874761
# 10   1999-05-28    AFL                Aflac  added     4977
# ..          ...    ...                  ...    ...      ...
# 497  1957-03-04    XEL          Xcel Energy  added    72903
# 498  1999-11-08   XLNX               Xilinx  added   743988
# 500  1997-10-06    YUM          Yum! Brands  added  1041061
# 502  2001-08-07    ZBH        Zimmer Biomet  added  1136869
# 503  2001-06-22   ZION        Zions Bancorp  added   109380
#
# [302 rows x 5 columns]

# %%
sp500_history = pd.concat([historical, missing])
sp500_history = sp500_history.sort_values(by=['date','ticker'], ascending=[False, True])
sp500_history
# Out:
#                   date ticker                    name   action        cik
# 112  September 8, 2016   CHTR  Charter Communications    added        NaN
# 112  September 8, 2016    EMC         EMC Corporation  removed        NaN
# 113  September 6, 2016    MTD          Mettler Toledo    added        NaN
# 113  September 6, 2016    TYC      Tyco International  removed        NaN
# 208  September 5, 2012    LYB          LyondellBasell    added        NaN
# ..                 ...    ...                     ...      ...        ...
# 484                NaN    WAT      Waters Corporation    added  1000697.0
# 493                NaN    WHR   Whirlpool Corporation    added   106640.0
# 483                NaN     WM        Waste Management    added   823768.0
# 491                NaN    WRK                WestRock    added  1732845.0
# 492                NaN     WY            Weyerhaeuser    added   106535.0
#
# [849 rows x 5 columns]

# %% [markdown]
# ## 5. Export to CSV

# %%
today = dt.datetime.today().strftime('%Y-%m-%d')
today
# Out:
# '2021-09-24'

# %%
current.to_csv(f"{today}-sp500.csv")
sp500_history.to_csv(f"{today}-sp500_history.csv")
